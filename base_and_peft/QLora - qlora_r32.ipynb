# %%
## Phase 2

# %% [markdown]
# ## Phase 2

# %%
# !pip uninstall -y trl transformers peft accelerate bitsandbytes
# Out:
# WARNING: Skipping trl as it is not installed.
# Found existing installation: transformers 5.0.0
# Uninstalling transformers-5.0.0:
#   Successfully uninstalled transformers-5.0.0
# Found existing installation: peft 0.18.1
# Uninstalling peft-0.18.1:
#   Successfully uninstalled peft-0.18.1
# Found existing installation: accelerate 1.12.0
# Uninstalling accelerate-1.12.0:
#   Successfully uninstalled accelerate-1.12.0
# WARNING: Skipping bitsandbytes as it is not installed.

# %%
# Install compatible stack
# !pip install -U --quiet \
transformers==4.45.2 \
peft==0.11.1 \
trl==0.9.6 \
accelerate \
bitsandbytes
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 80.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.6/251.6 kB 27.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.8/245.8 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.7/383.7 kB 38.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 41.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 51.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 126.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 121.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.9/181.9 kB 22.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# shap 0.50.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# cupy-cuda12x 14.0.1 requires numpy<2.6,>=2.0, but you have numpy 1.26.4 which is incompatible.
# tobler 0.13.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.

# %%
import transformers,trl,peft
import subprocess
import sys

# Verify the installed transformers version
try:
    result = subprocess.run([sys.executable, '-m', 'pip', 'show', 'transformers'], capture_output=True, text=True)
    if result.returncode == 0:
        print("--- Installed transformers package info ---")
        print(result.stdout)
    else:
        print("Could not get pip show transformers info.")
except Exception as e:
    print(f"Error checking pip show transformers: {e}")

print(f"--- Loaded module versions ---")
print(f"transformers.__version__: {transformers.__version__}")
print(f"trl.__version__: {trl.__version__}")
print(f"peft.__version__: {peft.__version__}")
# Out:
# --- Installed transformers package info ---
# Name: transformers
# Version: 4.45.2
# Summary: State-of-the-art Machine Learning for JAX, PyTorch and TensorFlow
# Home-page: https://github.com/huggingface/transformers
# Author: The Hugging Face team (past and future) with the help of all our contributors (https://github.com/huggingface/transformers/graphs/contributors)
# Author-email: transformers@huggingface.co
# License: Apache 2.0 License
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: filelock, huggingface-hub, numpy, packaging, pyyaml, regex, requests, safetensors, tokenizers, tqdm
# Required-by: peft, sentence-transformers, trl
#
# --- Loaded module versions ---
# transformers.__version__: 4.45.2
# trl.__version__: 0.9.6
# peft.__version__: 0.11.1

# %%
from google.colab import userdata
import os

# Retrieve the HF_TOKEN from Colab secrets
hf_token = userdata.get('HF_TOKEN')

# Set it as an environment variable
os.environ['HF_TOKEN'] = hf_token

print("HF_TOKEN loaded from Colab secrets and set as environment variable.")
# Now, when load_dataset is called, it will automatically use this token for authentication.
# Out:
# HF_TOKEN loaded from Colab secrets and set as environment variable.

# %%
# # ============================================================
# # Phase 2: PEFT Fine-tuning on CinePile (Text-Only)
# # Methods: QLoRA, Prefix Tuning, ReFT (LoReFT)
# # !pip install transformers datasets accelerate bitsandbytes peft trl pyreft
# # ============================================================

# import gc
# import os
# import torch
# import pandas as pd
# import numpy as np
# from abc import ABC, abstractmethod
# from dataclasses import dataclass, field
# from typing import Optional
# from datasets import load_dataset
# from transformers import (
#     AutoTokenizer,
#     AutoModelForCausalLM,
#     TrainingArguments,
#     BitsAndBytesConfig,
#     DataCollatorWithPadding,
# )
# from peft import (
#     LoraConfig,
#     PrefixTuningConfig,
#     get_peft_model,
#     TaskType,
#     PeftModel,
# )
# from trl import SFTTrainer, SFTConfig
# from tqdm import tqdm


# # ============================================================
# # 1. 配置类
# # ============================================================
# @dataclass
# class Phase2Config:
#     # --- 数据集 ---
#     dataset_name: str          = 'tomg-group-umd/cinepile'
#     train_split: str           = 'train'
#     test_split: str            = 'test'
#     max_train_samples: Optional[int] = 2000   # 调试用；None = 完整训练集
#     max_test_samples: Optional[int]  = 500    # 调试用；None = 完整测试集

#     # --- 基础模型（只选一个，节省显存）---
#     base_model_id: str         = 'meta-llama/Llama-3.1-8B-Instruct'

#     # --- 输入格式 ---
#     max_scene_length: int      = 1000   # 训练时截短以节省显存
#     max_seq_length: int        = 1024   # SFTTrainer 最大序列长度

#     # --- 训练通用参数 ---
#     num_train_epochs: int      = 2
#     per_device_train_batch_size: int = 2
#     gradient_accumulation_steps: int = 4   # 等效 batch size = 8
#     learning_rate: float       = 2e-4
#     warmup_ratio: float        = 0.05
#     lr_scheduler_type: str     = 'cosine'
#     fp16: bool                 = False
#     bf16: bool                 = True
#     logging_steps: int         = 20
#     save_steps: int            = 200
#     output_base_dir: str       = './phase2_outputs'

#     # --- QLoRA 参数 ---
#     lora_r: int                = 16
#     lora_alpha: int            = 32
#     lora_dropout: float        = 0.05
#     lora_target_modules: list  = field(default_factory=lambda: [
#         "q_proj", "k_proj", "v_proj", "o_proj",
#         "gate_proj", "up_proj", "down_proj"
#     ])

#     # --- Prefix Tuning 参数 ---
#     prefix_num_virtual_tokens: int = 20   # 也可以试 50

#     # --- ReFT (LoReFT) 参数 ---
#     reft_rank: int             = 4
#     reft_layers: list          = field(default_factory=lambda: [8, 16, 24])

#     # --- 评估 ---
#     max_new_tokens: int        = 5
#     output_csv: str            = 'phase2_results.csv'

#     # --- 类别映射（与 Phase 1 一致）---
#     category_map: dict = field(default_factory=lambda: {
#         'TEMP': 'Temporal',
#         'CRD':  'Character and',
#         'NPA':  'Narrative and',
#         'STA':  'Setting and',
#         'TH':   'Theme Exploration',
#     })


# # ============================================================
# # 2. 数据集（复用 Phase 1 的 answer_key 修复逻辑）
# # ============================================================
# class CinePileDataset:
#     LETTERS = ['A', 'B', 'C', 'D', 'E']

#     def __init__(self, config: Phase2Config):
#         self.config = config
#         self.train_data = self._load(config.train_split, config.max_train_samples)
#         self.test_data  = self._load(config.test_split,  config.max_test_samples)
#         print(f"[Dataset] Train: {len(self.train_data)} | Test: {len(self.test_data)}")

#     @classmethod
#     def _answer_text_to_letter(cls, answer_text: str, choices: list) -> str:
#         for i, c in enumerate(choices):
#             if answer_text.strip() == c.strip():
#                 return cls.LETTERS[i]
#         for i, c in enumerate(choices):
#             if answer_text.strip() in c or c.strip() in answer_text:
#                 return cls.LETTERS[i]
#         return 'A'

#     @staticmethod
#     def _normalize_hard_split(raw) -> bool:
#         if isinstance(raw, bool):
#             return raw
#         return str(raw).strip().lower() == 'true'

#     def _load(self, split: str, max_samples: Optional[int]) -> list:
#         raw = load_dataset(self.config.dataset_name, split=split)
#         samples = []
#         for ex in raw:
#             letter = self._answer_text_to_letter(ex['answer_key'], ex['choices'])
#             samples.append({
#                 'movie_scene':       ex['movie_scene'],
#                 'question':          ex['question'],
#                 'choices':           ex['choices'],
#                 'answer_key':        letter,
#                 'question_category': ex['question_category'],
#                 'hard_split':        self._normalize_hard_split(ex['hard_split']),
#             })
#         if max_samples:
#             samples = samples[:max_samples]
#         return samples


# # ============================================================
# # 3. Prompt 工具
# # ============================================================
# class PromptBuilder:
#     """
#     训练用：构造带答案的完整 prompt（供 SFTTrainer 做 causal LM 训练）
#     推理用：构造不含答案的 prompt（供 generate 输出）
#     """
#     @staticmethod
#     def build_train_prompt(sample: dict, max_scene_length: int) -> str:
#         scene   = sample['movie_scene'][:max_scene_length]
#         options = "\n".join(
#             f"{chr(65+i)}. {c}" for i, c in enumerate(sample['choices'])
#         )
#         answer  = sample['answer_key']
#         return (
#             f"You are watching a movie. Based on the scene description, "
#             f"answer the multiple choice question.\n\n"
#             f"Scene: {scene}\n\n"
#             f"Question: {sample['question']}\n\n"
#             f"Options:\n{options}\n\n"
#             f"Answer: {answer}"   # 训练时包含答案
#         )

#     @staticmethod
#     def build_inference_prompt(sample: dict, max_scene_length: int) -> str:
#         scene   = sample['movie_scene'][:max_scene_length]
#         options = "\n".join(
#             f"{chr(65+i)}. {c}" for i, c in enumerate(sample['choices'])
#         )
#         return (
#             f"You are watching a movie. Based on the scene description, "
#             f"answer the multiple choice question.\n\n"
#             f"Scene: {scene}\n\n"
#             f"Question: {sample['question']}\n\n"
#             f"Options:\n{options}\n\n"
#             f"Answer:"   # 推理时不含答案
#         )


# # ============================================================
# # 4. Evaluator（复用 Phase 1 逻辑）
# # ============================================================
# class Evaluator:
#     def __init__(self, config: Phase2Config):
#         self.config = config

#     def evaluate(self, model, tokenizer, test_data: list,
#                  method_name: str) -> dict:
#         model.eval()
#         records = []
#         for sample in tqdm(test_data, desc=f"  Evaluating {method_name}"):
#             pred = self._predict(model, tokenizer, sample)
#             records.append({
#                 'pred':              pred,
#                 'label':             sample['answer_key'],
#                 'question_category': sample['question_category'],
#                 'hard_split':        sample['hard_split'],
#             })
#         df = pd.DataFrame(records)
#         return self._compute_metrics(df)

#     def _predict(self, model, tokenizer, sample: dict) -> str:
#         prompt  = PromptBuilder.build_inference_prompt(
#             sample, self.config.max_scene_length
#         )
#         inputs  = tokenizer(
#             prompt,
#             return_tensors="pt",
#             truncation=True,
#             max_length=self.config.max_seq_length,
#         ).to(model.device)

#         with torch.no_grad():
#             outputs = model.generate(
#                 **inputs,
#                 max_new_tokens=self.config.max_new_tokens,
#                 do_sample=False,
#                 pad_token_id=tokenizer.eos_token_id,
#             )
#         decoded = tokenizer.decode(
#             outputs[0][inputs['input_ids'].shape[1]:],
#             skip_special_tokens=True,
#         ).strip().upper()

#         for char in decoded:
#             if char in 'ABCDE':
#                 return char
#         return 'A'

#     def _compute_metrics(self, df: pd.DataFrame) -> dict:
#         correct  = df['pred'] == df['label']
#         metrics  = {
#             'Overall':   correct.mean(),
#             'Overall_n': len(df),
#         }
#         for abbr, keyword in self.config.category_map.items():
#             mask = df['question_category'].str.contains(
#                 keyword, case=False, na=False
#             )
#             n = int(mask.sum())
#             metrics[abbr]        = correct[mask].mean() if n > 0 else None
#             metrics[f'{abbr}_n'] = n

#         hard_mask    = df['hard_split'] == True
#         n_hard       = int(hard_mask.sum())
#         metrics['Hard']   = correct[hard_mask].mean() if n_hard > 0 else None
#         metrics['Hard_n'] = n_hard
#         return metrics


# # ============================================================
# # 5. 基类 Trainer
# # ============================================================
# class BasePEFTTrainer(ABC):
#     def __init__(self, config: Phase2Config):
#         self.config    = config
#         self.model     = None
#         self.tokenizer = None
#         self.method_name = "base"

#     def _load_base_model_4bit(self):
#         """加载 4-bit 量化基础模型（QLoRA 用）"""
#         bnb_config = BitsAndBytesConfig(
#             load_in_4bit              = True,
#             bnb_4bit_use_double_quant = True,
#             bnb_4bit_quant_type       = "nf4",
#             bnb_4bit_compute_dtype    = torch.bfloat16,
#         )
#         tokenizer = AutoTokenizer.from_pretrained(self.config.base_model_id)
#         tokenizer.pad_token    = tokenizer.eos_token
#         tokenizer.padding_side = "right"

#         model = AutoModelForCausalLM.from_pretrained(
#             self.config.base_model_id,
#             quantization_config=bnb_config,
#             device_map="auto",
#         )
#         return model, tokenizer

#     def _load_base_model_bf16(self):
#         """加载 bf16 基础模型（Prefix Tuning / ReFT 用）"""
#         tokenizer = AutoTokenizer.from_pretrained(self.config.base_model_id)
#         tokenizer.pad_token    = tokenizer.eos_token
#         tokenizer.padding_side = "right"

#         model = AutoModelForCausalLM.from_pretrained(
#             self.config.base_model_id,
#             torch_dtype=torch.bfloat16,
#             device_map="auto",
#         )
#         return model, tokenizer

#     def _make_hf_dataset(self, data: list):
#         """将样本列表转为 HuggingFace Dataset（SFTTrainer 需要）"""
#         from datasets import Dataset
#         return Dataset.from_list([
#             {'text': PromptBuilder.build_train_prompt(
#                 s, self.config.max_scene_length
#             )}
#             for s in data
#         ])

#     def _output_dir(self) -> str:
#         path = os.path.join(self.config.output_base_dir, self.method_name)
#         os.makedirs(path, exist_ok=True)
#         return path

#     def free_memory(self):
#         if self.model is not None:
#             del self.model
#             self.model = None
#         if self.tokenizer is not None:
#             del self.tokenizer
#             self.tokenizer = None
#         gc.collect()
#         torch.cuda.empty_cache()
#         print(f"  [Memory freed] {self.method_name}")

#     @abstractmethod
#     def train(self, train_data: list): pass

#     @abstractmethod
#     def load_for_inference(self): pass


# # ============================================================
# # 6. QLoRA Trainer
# # ============================================================
# class QLoRATrainer(BasePEFTTrainer):
#     """
#     QLoRA: 4-bit 量化基础模型 + LoRA adapter
#     最成熟稳定，推理类问题（Causal / NPA）预期表现最好
#     """
#     def __init__(self, config: Phase2Config):
#         super().__init__(config)
#         self.method_name = f"qlora_r{config.lora_r}"

#     def train(self, train_data: list):
#         print(f"\n[QLoRA] Loading base model (4-bit)...")
#         model, tokenizer = self._load_base_model_4bit()

#         lora_config = LoraConfig(
#             r                = self.config.lora_r,
#             lora_alpha       = self.config.lora_alpha,
#             lora_dropout     = self.config.lora_dropout,
#             target_modules   = self.config.lora_target_modules,
#             bias             = "none",
#             task_type        = TaskType.CAUSAL_LM,
#         )

#         train_args = SFTConfig(
#             output_dir                  = self._output_dir(),
#             num_train_epochs            = self.config.num_train_epochs,
#             per_device_train_batch_size = self.config.per_device_train_batch_size,
#             gradient_accumulation_steps = self.config.gradient_accumulation_steps,
#             learning_rate               = self.config.learning_rate,
#             warmup_ratio                = self.config.warmup_ratio,
#             lr_scheduler_type           = self.config.lr_scheduler_type,
#             bf16                        = self.config.bf16,
#             logging_steps               = self.config.logging_steps,
#             save_steps                  = self.config.save_steps,
#             max_seq_length              = self.config.max_seq_length,
#             dataset_text_field          = "text",
#             report_to                   = "none",
#             gradient_checkpointing      = True,
#             optim                       = "paged_adamw_8bit",
#         )

#         hf_dataset = self._make_hf_dataset(train_data)

#         trainer = SFTTrainer(
#             model         = model,
#             args          = train_args,
#             train_dataset = hf_dataset,
#             peft_config   = lora_config,
#             tokenizer     = tokenizer,
#         )

#         print(f"[QLoRA] Training... (samples={len(train_data)})")
#         trainer.train()
#         trainer.save_model(self._output_dir())
#         tokenizer.save_pretrained(self._output_dir())
#         print(f"[QLoRA] Saved → {self._output_dir()}")

#         self.model     = trainer.model
#         self.tokenizer = tokenizer

#     def load_for_inference(self):
#         """从保存的 checkpoint 加载用于推理"""
#         print(f"[QLoRA] Loading from {self._output_dir()}")
#         model, tokenizer = self._load_base_model_4bit()
#         self.model     = PeftModel.from_pretrained(model, self._output_dir())
#         self.tokenizer = tokenizer


# # ============================================================
# # 7. Prefix Tuning Trainer
# # ============================================================
# class PrefixTuningTrainer(BasePEFTTrainer):
#     """
#     Prefix Tuning: 在每层添加可学习 virtual tokens
#     对长序列上下文任务（Temporal / CRD）预期有优势
#     注意：Prefix Tuning 不兼容 4-bit，需要 bf16 全精度基础模型
#     """
#     def __init__(self, config: Phase2Config):
#         super().__init__(config)
#         self.method_name = f"prefix_vt{config.prefix_num_virtual_tokens}"

#     def train(self, train_data: list):
#         print(f"\n[Prefix] Loading base model (bf16)...")
#         model, tokenizer = self._load_base_model_bf16()

#         prefix_config = PrefixTuningConfig(
#             task_type          = TaskType.CAUSAL_LM,
#             num_virtual_tokens = self.config.prefix_num_virtual_tokens,
#             prefix_projection  = True,   # MLP 投影，比直接优化更稳定
#         )

#         model = get_peft_model(model, prefix_config)
#         model.print_trainable_parameters()

#         train_args = SFTConfig(
#             output_dir                  = self._output_dir(),
#             num_train_epochs            = self.config.num_train_epochs,
#             per_device_train_batch_size = self.config.per_device_train_batch_size,
#             gradient_accumulation_steps = self.config.gradient_accumulation_steps,
#             learning_rate               = 1e-3,   # Prefix Tuning 需要更大 lr
#             warmup_ratio                = self.config.warmup_ratio,
#             lr_scheduler_type           = self.config.lr_scheduler_type,
#             bf16                        = self.config.bf16,
#             logging_steps               = self.config.logging_steps,
#             save_steps                  = self.config.save_steps,
#             max_seq_length              = self.config.max_seq_length,
#             dataset_text_field          = "text",
#             report_to                   = "none",
#             gradient_checkpointing      = False,  # Prefix Tuning 不兼容 grad ckpt
#         )

#         hf_dataset = self._make_hf_dataset(train_data)

#         trainer = SFTTrainer(
#             model         = model,
#             args          = train_args,
#             train_dataset = hf_dataset,
#             tokenizer     = tokenizer,
#         )

#         print(f"[Prefix] Training... (samples={len(train_data)})")
#         trainer.train()
#         trainer.save_model(self._output_dir())
#         tokenizer.save_pretrained(self._output_dir())
#         print(f"[Prefix] Saved → {self._output_dir()}")

#         self.model     = model
#         self.tokenizer = tokenizer

#     def load_for_inference(self):
#         print(f"[Prefix] Loading from {self._output_dir()}")
#         model, tokenizer = self._load_base_model_bf16()
#         self.model     = PeftModel.from_pretrained(model, self._output_dir())
#         self.tokenizer = tokenizer


# # ============================================================
# # 8. ReFT (LoReFT) Trainer
# # ============================================================
# class ReFTTrainer(BasePEFTTrainer):
#     """
#     ReFT / LoReFT: 在 representation 空间做低秩线性干预
#     参数极少 (<0.1%)，新方法，作为探索性对比
#     依赖: pip install pyreft
#     """
#     def __init__(self, config: Phase2Config):
#         super().__init__(config)
#         self.method_name = f"reft_r{config.reft_rank}"

#     def train(self, train_data: list):
#         try:
#             import pyreft
#         except ImportError:
#             print("[ReFT] pyreft not installed. Run: pip install pyreft")
#             return

#         print(f"\n[ReFT] Loading base model (bf16)...")
#         model, tokenizer = self._load_base_model_bf16()

#         # 在指定层应用 LoReFT 干预
#         reft_config = pyreft.ReftConfig(
#             representations=[
#                 {
#                     "layer"           : l,
#                     "component"       : "block_output",
#                     "low_rank_dimension": self.config.reft_rank,
#                     "intervention"    : pyreft.LoreftIntervention(
#                         embed_dim          = model.config.hidden_size,
#                         low_rank_dimension = self.config.reft_rank,
#                     )
#                 }
#                 for l in self.config.reft_layers
#             ]
#         )
#         reft_model = pyreft.get_reft_model(model, reft_config)
#         reft_model.print_trainable_parameters()

#         # 构造训练数据（ReFT 用自己的 DataCollator）
#         train_dataset = self._make_reft_dataset(
#             train_data, tokenizer, pyreft
#         )

#         training_args = TrainingArguments(
#             output_dir                  = self._output_dir(),
#             num_train_epochs            = self.config.num_train_epochs,
#             per_device_train_batch_size = self.config.per_device_train_batch_size,
#             gradient_accumulation_steps = self.config.gradient_accumulation_steps,
#             learning_rate               = self.config.learning_rate,
#             warmup_ratio                = self.config.warmup_ratio,
#             bf16                        = self.config.bf16,
#             logging_steps               = self.config.logging_steps,
#             save_steps                  = self.config.save_steps,
#             report_to                   = "none",
#         )

#         reft_trainer = pyreft.ReftTrainerForCausalLM(
#             model         = reft_model,
#             args          = training_args,
#             train_dataset = train_dataset,
#             tokenizer     = tokenizer,
#             data_collator = pyreft.ReftDataCollator(
#                 data_collator=DataCollatorWithPadding(tokenizer)
#             ),
#         )

#         print(f"[ReFT] Training... (samples={len(train_data)})")
#         reft_trainer.train()
#         reft_model.save(self._output_dir())
#         tokenizer.save_pretrained(self._output_dir())
#         print(f"[ReFT] Saved → {self._output_dir()}")

#         self.model     = reft_model
#         self.tokenizer = tokenizer

#     def _make_reft_dataset(self, data, tokenizer, pyreft):
#         """将样本转换为 ReFT 所需的 dataset 格式"""
#         from datasets import Dataset
#         prompts, outputs = [], []
#         for s in data:
#             prompt = PromptBuilder.build_inference_prompt(
#                 s, self.config.max_scene_length
#             )
#             prompts.append(prompt)
#             outputs.append(s['answer_key'])

#         return pyreft.make_last_position_supervised_data_module(
#             tokenizer     = tokenizer,
#             model         = self.model,
#             inputs        = prompts,
#             outputs       = outputs,
#             num_interventions = len(self.config.reft_layers),
#         )

#     def load_for_inference(self):
#         try:
#             import pyreft
#         except ImportError:
#             print("[ReFT] pyreft not installed.")
#             return

#         print(f"[ReFT] Loading from {self._output_dir()}")
#         model, tokenizer = self._load_base_model_bf16()
#         self.model     = pyreft.ReftModel.load(self._output_dir(), model)
#         self.tokenizer = tokenizer


# # ============================================================
# # 9. Phase2 主运行器
# # ============================================================
# class Phase2Runner:
#     def __init__(self, config: Phase2Config):
#         self.config      = config
#         self.dataset     = CinePileDataset(config)
#         self.evaluator   = Evaluator(config)
#         self.all_metrics = {}

#         # 注册要运行的 PEFT 方法
#         self.trainers = [
#             # QLoRATrainer(config),
#             # PrefixTuningTrainer(config),
#             ReFTTrainer(config),
#         ]

#     def run(self):
#         print("\n" + "="*60)
#         print("PHASE 2: PEFT Fine-tuning on CinePile")
#         print(f"Base model : {self.config.base_model_id}")
#         print(f"Train size : {len(self.dataset.train_data)}")
#         print(f"Test size  : {len(self.dataset.test_data)}")
#         print("="*60)

#         for trainer in self.trainers:
#             print(f"\n{'='*60}")
#             print(f"Method: {trainer.method_name.upper()}")
#             print(f"{'='*60}")

#             # 1. 训练
#             trainer.train(self.dataset.train_data)

#             # 2. 评估
#             if trainer.model is not None:
#                 metrics = self.evaluator.evaluate(
#                     trainer.model,
#                     trainer.tokenizer,
#                     self.dataset.test_data,
#                     trainer.method_name,
#                 )
#                 self.all_metrics[trainer.method_name] = metrics
#                 hard_str = (f"{metrics['Hard']:.2%}"
#                             if metrics.get('Hard') is not None else "N/A")
#                 print(f"  Overall: {metrics['Overall']:.2%} "
#                       f"| Hard: {hard_str}")

#             # 3. 释放显存
#             trainer.free_memory()

#         self._display_and_save()

#     def _display_and_save(self):
#         display_cols = ['Overall', 'TEMP', 'CRD', 'NPA', 'STA', 'TH', 'Hard']
#         rows = []
#         for method_name, metrics in self.all_metrics.items():
#             row = {'Method': method_name}
#             for col in display_cols:
#                 val = metrics.get(col)
#                 n   = metrics.get(f'{col}_n', metrics.get('Overall_n', ''))
#                 row[col] = f"{val:.1%}(n={n})" if val is not None else 'N/A'
#             rows.append(row)

#         df = pd.DataFrame(rows)
#         print("\n" + "="*60)
#         print("PHASE 2 FINAL RESULTS — CinePile PEFT Fine-tuning")
#         print("="*60)
#         print(df.to_string(index=False))
#         df.to_csv(self.config.output_csv, index=False)
#         print(f"\nSaved → {self.config.output_csv}")


# # ============================================================
# # 10. 入口
# # ============================================================
# if __name__ == '__main__':

#     config = Phase2Config(
#         base_model_id        = 'meta-llama/Llama-3.1-8B-Instruct',
#         max_train_samples    = 20,   # 调试：2000；完整：None
#         max_test_samples     = 500,    # 调试：500； 完整：None
#         num_train_epochs     = 2,
#         lora_r               = 16,
#         prefix_num_virtual_tokens = 20,
#         reft_rank            = 4,
#         reft_layers          = [8, 16, 24],
#         output_base_dir      = './phase2_outputs',
#         output_csv           = 'phase2_results.csv',
#     )

#     runner = Phase2Runner(config)
#     runner.run()

# %% [markdown]
# ## 2.2 QLoRA and Prefix Tuning

# %%
# 如果在 Colab + Google Drive:
from google.colab import drive
drive.mount('/content/drive')
PROJECT_DIR = "/content/drive/MyDrive/Datasci_266_NLP/Final Project/CinePile_Phase2"
os.makedirs(PROJECT_DIR, exist_ok=True)
# Out:
# Mounted at /content/drive

# %%
# ============================================================
# Phase 2: QLoRA + Prefix Tuning on CinePile (with Stratified Sampling & Checkpoints)
# Requirements:
#   pip install transformers datasets accelerate bitsandbytes peft trl
# ============================================================

import os
import gc
from dataclasses import dataclass, field
from typing import Optional, List, Dict
from datetime import datetime
from collections import defaultdict

import torch
import pandas as pd
from datasets import load_dataset, Dataset
from tqdm import tqdm

from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    BitsAndBytesConfig,
)
from peft import (
    LoraConfig,
    PrefixTuningConfig,
    get_peft_model,
    TaskType,
)
from trl import SFTTrainer, SFTConfig


# ============================================================
# 1. 配置
# ============================================================
@dataclass
class Phase2Config:
    # 数据集
    dataset_name: str          = "tomg-group-umd/cinepile"
    train_split: str           = "train"
    test_split: str            = "test"

    # 分层抽样（None = 用完整 split）
    max_train_samples: Optional[int] = 30000   # e.g. 从 ~30 万中抽 3 万
    max_test_samples: Optional[int]  = 500     # 测试集可截断或用 full

    # hard 样本在分层抽样中的额外倍率（>1 表示更偏向抽 hard）
    hard_oversample_ratio: float     = 1.5

    # 模型
    base_model_id: str         = "meta-llama/Llama-3.1-8B-Instruct"

    # 输入长度
    max_scene_length: int      = 1200   ### Change from 1000 to 1200 (allow more scene context)
    max_seq_length: int        = 1536   ### Change from 1024 to 1536 (better reasoning window)

    # 通用训练参数
    num_train_epochs: int      = 4      ### Change from 3 to 4 (LoRA rarely overfits, improves learning)
    per_device_train_batch_size: int = 4   ### Change from 4 to 1 (T4 VRAM stability)
    gradient_accumulation_steps: int = 4  ### Change from 4 to 16 (keep effective batch size ≈16)
    learning_rate: float       = 2e-4
    warmup_ratio: float        = 0.05
    lr_scheduler_type: str     = "cosine"

    bf16: bool                 = True   ### Change to True for A100
    fp16: bool                 = False

    logging_steps: int         = 50

    # checkpoint & 输出
    save_steps: int            = 200
    save_total_limit: int      = 3
    output_base_dir: str       = "./phase2_outputs"
    output_csv: str            = "phase2_results.csv"

    # QLoRA
    lora_r: int                = 32 ### Consider a higher value if the model is struggling to capture the complexity
    lora_alpha: int            = 64
    lora_dropout: float        = 0.0 ### Since we have big example sizes (30000), maybe try 0
    lora_target_modules: List[str] = field(default_factory=lambda: [
        "q_proj", "k_proj", "v_proj", "o_proj",
        "gate_proj", "up_proj", "down_proj",
    ]) ### Recommend all 7 layers, but might also try less

    # Prefix Tuning
    prefix_num_virtual_tokens: int = 20

    # 评估生成长度
    max_new_tokens: int        = 2

    # 类别映射
    category_map: Dict[str, str] = field(default_factory=lambda: {
        "TEMP": "Temporal",
        "CRD":  "Character and",
        "NPA":  "Narrative and",
        "STA":  "Setting and",
        "TH":   "Theme Exploration",
    })


# ============================================================
# 2. Stratified Sampler（按类别 × hard 分层抽样）
# ============================================================
class StratifiedSampler:
    def __init__(self, cfg: Phase2Config):
        self.cfg = cfg

    def sample(self, data: list) -> list:
        if self.cfg.max_train_samples is None:
            print(f"[Sampler] Using full train split: {len(data)} samples")
            return data

        target = self.cfg.max_train_samples

        # 按 (category_key, hard) 分组
        groups = defaultdict(list)
        for s in data:
            cat  = self._get_category_key(s["question_category"])
            hard = bool(s["hard_split"])
            groups[(cat, hard)].append(s)

        n_categories = len(set(k[0] for k in groups))
        # 理论 strata = 每个类别 × hard/easy
        base_quota = target / (n_categories * (1 + self.cfg.hard_oversample_ratio))
        easy_q     = base_quota
        hard_q     = base_quota * self.cfg.hard_oversample_ratio

        sampled = []
        report  = []

        import random
        random.seed(42) # same seed using in ReFT part

        for (cat, hard), group in sorted(groups.items()):
            quota  = int(hard_q if hard else easy_q)
            n_take = min(quota, len(group))
            taken  = random.sample(group, n_take)
            sampled.extend(taken)
            report.append({
                "category":  cat,
                "hard":      hard,
                "available": len(group),
                "quota":     quota,
                "sampled":   n_take,
            })

        # 若仍不足 target，从剩余中补齐
        if len(sampled) < target:
            sampled_ids = set(id(s) for s in sampled)
            remaining   = [s for s in data if id(s) not in sampled_ids]
            extra = random.sample(
                remaining, min(target - len(sampled), len(remaining))
            )
            sampled.extend(extra)

        self._print_report(report, len(sampled))
        return sampled

    def _get_category_key(self, cat_str: str) -> str:
        for abbr, kw in self.cfg.category_map.items():
            if kw.lower() in cat_str.lower():
                return abbr
        return "OTHER"

    @staticmethod
    def _print_report(report: list, total_sampled: int):
        df = pd.DataFrame(report)
        print("\n[Sampler] ===== Stratified Sampling Report =====")
        print(df.to_string(index=False))
        print(f"[Sampler] Total sampled: {total_sampled}")
        print("[Sampler] " + "=" * 60)


# ============================================================
# 3. ExperimentTracker（记录每次实验参数 + 结果）
# ============================================================
class ExperimentTracker:
    def __init__(self, log_path: str = "./phase2_experiments_log.csv"):
        self.log_path = log_path

    def log(self, method_name: str, cfg: Phase2Config, metrics: dict):
        record = {
            "timestamp":           datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
            "method":              method_name,
            "base_model":          cfg.base_model_id.split("/")[-1],
            "max_train_samples":   cfg.max_train_samples if cfg.max_train_samples else "full",
            "max_test_samples":    cfg.max_test_samples  if cfg.max_test_samples  else "full",
            "hard_oversample":     cfg.hard_oversample_ratio,
            "num_train_epochs":    cfg.num_train_epochs,
            "lora_r":              cfg.lora_r,
            "prefix_tokens":       cfg.prefix_num_virtual_tokens,
            "learning_rate":       cfg.learning_rate,
            "batch_size":          cfg.per_device_train_batch_size,
            "grad_accum":          cfg.gradient_accumulation_steps,
            # metrics
            "Overall": metrics.get("Overall"),
            "TEMP":    metrics.get("TEMP"),
            "CRD":     metrics.get("CRD"),
            "NPA":     metrics.get("NPA"),
            "STA":     metrics.get("STA"),
            "TH":      metrics.get("TH"),
            "Hard":    metrics.get("Hard"),
            "n_test":  metrics.get("Overall_n"),
            "n_TEMP":  metrics.get("TEMP_n"),
            "n_CRD":   metrics.get("CRD_n"),
            "n_NPA":   metrics.get("NPA_n"),
            "n_STA":   metrics.get("STA_n"),
            "n_TH":    metrics.get("TH_n"),
            "n_Hard":  metrics.get("Hard_n"),
        }
        df_new = pd.DataFrame([record])
        if os.path.exists(self.log_path):
            df_old = pd.read_csv(self.log_path)
            df_all = pd.concat([df_old, df_new], ignore_index=True)
        else:
            df_all = df_new
        df_all.to_csv(self.log_path, index=False)
        print(f"[Tracker] Logged {method_name} → {self.log_path}")
        return df_all


# ============================================================
# 4. 数据加载 & 预处理
# ============================================================
class CinePileDataset:
    LETTERS = ["A", "B", "C", "D", "E"]

    def __init__(self, cfg: Phase2Config):
        self.cfg = cfg
        self.train_data, self.test_data = self._load_all()
        print(f"[Dataset] Train: {len(self.train_data)} | Test: {len(self.test_data)}")

    @classmethod
    def _answer_text_to_letter(cls, answer_text: str, choices: list) -> str:
        for i, c in enumerate(choices):
            if answer_text.strip() == c.strip():
                return cls.LETTERS[i]
        for i, c in enumerate(choices):
            if answer_text.strip() in c or c.strip() in answer_text:
                return cls.LETTERS[i]
        return "A"

    @staticmethod
    def _normalize_hard_split(raw) -> bool:
        if isinstance(raw, bool):
            return raw
        return str(raw).strip().lower() == "true"

    def _load_split(self, split: str) -> list:
        raw = load_dataset(self.cfg.dataset_name, split=split)
        samples = []
        for ex in raw:
            letter = self._answer_text_to_letter(ex["answer_key"], ex["choices"])
            samples.append({
                "movie_scene":       ex["movie_scene"],
                "question":          ex["question"],
                "choices":           ex["choices"],
                "answer_key":        letter,
                "question_category": ex["question_category"],
                "hard_split":        self._normalize_hard_split(ex["hard_split"]),
            })
        return samples

    def _load_all(self):
        train_raw = self._load_split(self.cfg.train_split)
        test_raw  = self._load_split(self.cfg.test_split)

        # 训练集分层抽样
        sampler    = StratifiedSampler(self.cfg)
        train_data = sampler.sample(train_raw)

        # 测试集截断
        if self.cfg.max_test_samples:
            test_data = test_raw[:self.cfg.max_test_samples]
        else:
            test_data = test_raw

        return train_data, test_data


# ============================================================
# 5. Prompt Builder & Evaluator
# ============================================================
class PromptBuilder:
    @staticmethod
    def build_train_prompt(sample: dict, max_scene_length: int) -> str:
        scene   = sample["movie_scene"][:max_scene_length]
        options = "\n".join(
            f"{chr(65+i)}. {c}" for i, c in enumerate(sample["choices"])
        )
        return (
            "You are watching a movie. Based on the scene description, "
            "answer the multiple choice question.\n\n"
            f"Scene: {scene}\n\n"
            f"Question: {sample['question']}\n\n"
            f"Think briefly about the scene before choosing the answer.\n\n"
            f"Options:\n{options}\n\n"
            f"Answer (A/B/C/D/E): {sample['answer_key']}"
        )

    @staticmethod
    def build_inference_prompt(sample: dict, max_scene_length: int) -> str:
        scene   = sample["movie_scene"][:max_scene_length]
        options = "\n".join(
            f"{chr(65+i)}. {c}" for i, c in enumerate(sample["choices"])
        )
        return (
            "You are watching a movie. Based on the scene description, "
            "answer the multiple choice question.\n\n"
            f"Scene: {scene}\n\n"
            f"Question: {sample['question']}\n\n"
            f"Think briefly about the scene before choosing the answer.\n\n"
            f"Options:\n{options}\n\n"
            "Answer (A/B/C/D/E):"
        )


class Evaluator:
    def __init__(self, cfg: Phase2Config):
        self.cfg = cfg

    def evaluate(self, model, tokenizer, test_data: list, method_name: str) -> dict:
        model.eval()
        records = []
        for s in tqdm(test_data, desc=f"Eval {method_name}"):
            pred = self._predict(model, tokenizer, s)
            records.append({
                "pred":              pred,
                "label":             s["answer_key"],
                "question_category": s["question_category"],
                "hard_split":        s["hard_split"],
            })
        df = pd.DataFrame(records)
        return self._compute_metrics(df)

    def _predict(self, model, tokenizer, sample: dict) -> str:
        prompt = PromptBuilder.build_inference_prompt(sample, self.cfg.max_scene_length)
        inputs = tokenizer(
            prompt,
            return_tensors="pt",
            truncation=True,
            max_length=self.cfg.max_seq_length,
        ).to(model.device)

        inputs = {k: v.to(model.device) for k, v in inputs.items()} ## Add this line

        # model = model.to(torch.bfloat16) ## To correct expected scalar type Float but found BFloat16 error

        with torch.no_grad():
            outputs = model.generate(
                **inputs,
                max_new_tokens=self.cfg.max_new_tokens,
                do_sample=False,
                pad_token_id=tokenizer.eos_token_id,
            )
        decoded = tokenizer.decode(
            outputs[0][inputs["input_ids"].shape[1]:],
            skip_special_tokens=True,
        ).strip().upper()

        import re

        match = re.search(r"\b([A-E])\b", decoded)
        if match:
            return match.group(1)

        return "A"

    def _compute_metrics(self, df: pd.DataFrame) -> dict:
        correct = df["pred"] == df["label"]
        metrics = {
            "Overall":   correct.mean(),
            "Overall_n": len(df),
        }
        for abbr, keyword in self.cfg.category_map.items():
            mask = df["question_category"].str.contains(keyword, case=False, na=False)
            n    = int(mask.sum())
            metrics[abbr]        = correct[mask].mean() if n > 0 else None
            metrics[f"{abbr}_n"] = n

        hard_mask = df["hard_split"] == True
        n_hard    = int(hard_mask.sum())
        metrics["Hard"]   = correct[hard_mask].mean() if n_hard > 0 else None
        metrics["Hard_n"] = n_hard
        return metrics


# ============================================================
# 6. 基类 Trainer
# ============================================================
class BasePEFTTrainer:
    def __init__(self, cfg: Phase2Config, method_name: str):
        self.cfg         = cfg
        self.method_name = method_name
        self.model       = None
        self.tokenizer   = None

    def _output_dir(self) -> str:
        path = os.path.join(self.cfg.output_base_dir, self.method_name)
        os.makedirs(path, exist_ok=True)
        return path

    def _make_hf_dataset(self, data: list) -> Dataset:
        return Dataset.from_list([
            {"text": PromptBuilder.build_train_prompt(s, self.cfg.max_scene_length)}
            for s in data
        ])

    def free_memory(self):
        if self.model is not None:
            del self.model
        if self.tokenizer is not None:
            del self.tokenizer
        self.model = None
        self.tokenizer = None
        gc.collect()
        torch.cuda.empty_cache()
        print(f"[Memory] Freed for {self.method_name}")


# ============================================================
# 7. QLoRA Trainer（含 checkpoint）
# ============================================================
class QLoRATrainer(BasePEFTTrainer):
    def __init__(self, cfg: Phase2Config):
        super().__init__(cfg, method_name=f"qlora_r{cfg.lora_r}")

    def _load_base_model_4bit(self):

        bnb_config = BitsAndBytesConfig(
            load_in_4bit              = True,
            bnb_4bit_use_double_quant = True,
            bnb_4bit_quant_type       = "nf4",

            bnb_4bit_compute_dtype=torch.bfloat16

            ### Recover bfloat16 for A100

        )

        tokenizer = AutoTokenizer.from_pretrained(self.cfg.base_model_id)

        tokenizer.pad_token    = tokenizer.eos_token
        tokenizer.padding_side = "right"

        model = AutoModelForCausalLM.from_pretrained(
            self.cfg.base_model_id,
            quantization_config=bnb_config,
            device_map="auto",
        )

        return model, tokenizer

    def train(self, train_data: list):
        print(f"\n[QLoRA] Loading base model (4-bit)...")
        model, tokenizer = self._load_base_model_4bit()

        lora_config = LoraConfig(
            r              = self.cfg.lora_r,
            lora_alpha     = self.cfg.lora_alpha,
            lora_dropout   = self.cfg.lora_dropout,
            target_modules = self.cfg.lora_target_modules,
            bias           = "none",
            task_type      = TaskType.CAUSAL_LM,
        )

        args = SFTConfig(
            output_dir                  = self._output_dir(),
            num_train_epochs            = self.cfg.num_train_epochs,
            per_device_train_batch_size = self.cfg.per_device_train_batch_size,
            gradient_accumulation_steps = self.cfg.gradient_accumulation_steps,
            learning_rate               = self.cfg.learning_rate,
            warmup_ratio                = self.cfg.warmup_ratio,
            lr_scheduler_type           = self.cfg.lr_scheduler_type,

            bf16=self.cfg.bf16,
            fp16=self.cfg.fp16,
            ### Added fp16=True support for T4 GPU

            logging_steps               = self.cfg.logging_steps,

            save_strategy               = "steps",
            save_steps                  = self.cfg.save_steps,
            save_total_limit            = self.cfg.save_total_limit,
            max_seq_length              = self.cfg.max_seq_length, # Move to SFTTrainer
            # dataset_text_field          = "text",
            report_to                   = "none",
            gradient_checkpointing      = True,
            optim                       = "paged_adamw_8bit",
        )

        hf_dataset = self._make_hf_dataset(train_data)
        trainer = SFTTrainer(
            model         = model,
            args          = args,
            train_dataset = hf_dataset,
            peft_config   = lora_config,
            tokenizer     = tokenizer,


            dataset_text_field = 'text', # Improve GPU utilization
            packing       = False, # Improve GPU utilization

        )

        print(f"[QLoRA] Training on {len(train_data)} samples...")
        trainer.train()
        trainer.save_model(self._output_dir())
        tokenizer.save_pretrained(self._output_dir())
        print(f"[QLoRA] Saved → {self._output_dir()}")

        self.model     = trainer.model
        self.tokenizer = tokenizer


# ============================================================
# 8. Prefix Tuning Trainer（含 checkpoint）
# ============================================================
class PrefixTuningTrainer(BasePEFTTrainer):
    def __init__(self, cfg: Phase2Config):
        super().__init__(cfg, method_name=f"prefix_vt{cfg.prefix_num_virtual_tokens}")

    def _load_base_model_bf16(self):
        tokenizer = AutoTokenizer.from_pretrained(self.cfg.base_model_id)
        tokenizer.pad_token    = tokenizer.eos_token
        tokenizer.padding_side = "right"
        model = AutoModelForCausalLM.from_pretrained(
            self.cfg.base_model_id,
            torch_dtype=torch.bfloat16,
            device_map="auto",
        )
        return model, tokenizer

    def train(self, train_data: list):
        print(f"\n[Prefix] Loading base model (bf16)...")
        model, tokenizer = self._load_base_model_bf16()

        prefix_config = PrefixTuningConfig(
            task_type          = TaskType.CAUSAL_LM,
            num_virtual_tokens = self.cfg.prefix_num_virtual_tokens,
            prefix_projection  = True,
        )
        model = get_peft_model(model, prefix_config)
        model.print_trainable_parameters()

        args = SFTConfig(
            output_dir                  = self._output_dir(),
            num_train_epochs            = self.cfg.num_train_epochs,
            per_device_train_batch_size = self.cfg.per_device_train_batch_size,
            gradient_accumulation_steps = self.cfg.gradient_accumulation_steps,
            learning_rate               = 1e-3,   # Prefix 一般 lr 更大
            warmup_ratio                = self.cfg.warmup_ratio,
            lr_scheduler_type           = self.cfg.lr_scheduler_type,
            bf16                        = self.cfg.bf16,
            logging_steps               = self.cfg.logging_steps,
            save_strategy               = "steps",
            save_steps                  = self.cfg.save_steps,
            save_total_limit            = self.cfg.save_total_limit,
            max_seq_length              = self.cfg.max_seq_length,
            dataset_text_field          = "text",
            report_to                   = "none",
            gradient_checkpointing      = False,
        )

        hf_dataset = self._make_hf_dataset(train_data)
        trainer = SFTTrainer(
            model         = model,
            args          = args,
            train_dataset = hf_dataset,
            tokenizer     = tokenizer,
        )

        print(f"[Prefix] Training on {len(train_data)} samples...")
        trainer.train()
        trainer.save_model(self._output_dir())
        tokenizer.save_pretrained(self._output_dir())
        print(f"[Prefix] Saved → {self._output_dir()}")

        self.model     = trainer.model
        self.tokenizer = tokenizer


# ============================================================
# 9. Phase2 Runner
# ============================================================
class Phase2Runner:
    def __init__(self, cfg: Phase2Config, tracker: Optional[ExperimentTracker] = None):
        self.cfg      = cfg
        self.dataset  = CinePileDataset(cfg)
        self.evaluator = Evaluator(cfg)
        self.tracker  = tracker
        self.results  = {}

        self.trainers = [
            QLoRATrainer(cfg),
            # PrefixTuningTrainer(cfg),
        ]

    def run(self):
        print("\n" + "=" * 70)
        print("PHASE 2: QLoRA + Prefix Tuning with Stratified Sampling")
        print(f"Base model : {self.cfg.base_model_id}")
        print(f"Train size : {len(self.dataset.train_data)} (after sampling)")
        print(f"Test size  : {len(self.dataset.test_data)}")
        print("=" * 70)

        for trainer in self.trainers:
            print("\n" + "=" * 70)
            print(f"Method: {trainer.method_name.upper()}")
            print("=" * 70)

            trainer.train(self.dataset.train_data)

            metrics = self.evaluator.evaluate(
                trainer.model,
                trainer.tokenizer,
                self.dataset.test_data,
                trainer.method_name,
            )
            self.results[trainer.method_name] = metrics

            hard_str = (f"{metrics['Hard']:.2%}"
                        if metrics.get("Hard") is not None else "N/A")
            print(f"[{trainer.method_name}] Overall: {metrics['Overall']:.2%} | Hard: {hard_str}")

            if self.tracker is not None:
                self.tracker.log(trainer.method_name, self.cfg, metrics)

            trainer.free_memory()

        self._display_and_save()

    def _display_and_save(self):
        display_cols = ["Overall", "TEMP", "CRD", "NPA", "STA", "TH", "Hard"]
        rows = []
        for method, metrics in self.results.items():
            row = {"Method": method}
            for col in display_cols:
                val = metrics.get(col)
                n   = metrics.get(f"{col}_n", metrics.get("Overall_n", ""))
                row[col] = f"{val:.1%}(n={n})" if val is not None else "N/A"
            rows.append(row)

        df = pd.DataFrame(rows)
        print("\n" + "=" * 70)
        print("PHASE 2 FINAL RESULTS — QLoRA + Prefix (Stratified 30k)")
        print("=" * 70)
        print(df.to_string(index=False))
        df.to_csv(self.cfg.output_csv, index=False)
        print(f"\n[Phase2] Saved table → {self.cfg.output_csv}")


# ============================================================
# 10. 入口示例
# ============================================================
if __name__ == "__main__":
    import transformers
    print("transformers:", transformers.__version__)

    # # 如果在 Colab + Google Drive:
    # from google.colab import drive
    # drive.mount('/content/drive')
    # PROJECT_DIR = "/content/drive/MyDrive/Datasci_266_NLP/Final Project/CinePile_Phase2"
    # os.makedirs(PROJECT_DIR, exist_ok=True)


    tracker = ExperimentTracker(
        log_path=os.path.join(PROJECT_DIR, "phase2_experiments_log.csv")
    )

    cfg = Phase2Config(
        base_model_id               = "meta-llama/Llama-3.1-8B-Instruct",
        max_train_samples           = 30000,    # 从约30万中抽3万
        max_test_samples            = 500,
        hard_oversample_ratio       = 1.5,

        num_train_epochs            = 4,   ### Change from 3 to 4
        per_device_train_batch_size = 4,   ### Change from 4 to 1
        gradient_accumulation_steps = 4,   ### Change from 4 to 16

        learning_rate               = 2e-4,
        output_base_dir             = PROJECT_DIR,
        output_csv                  = os.path.join(PROJECT_DIR, "phase2_results.csv"),
    )

    runner = Phase2Runner(cfg, tracker=tracker)
    runner.run()
# Out:
# transformers: 4.45.2
# README.md: 0.00B [00:00, ?B/s]
# v2/train-00000-of-00003.parquet:   0%|          | 0.00/21.9M [00:00<?, ?B/s]
# v2/train-00001-of-00003.parquet:   0%|          | 0.00/23.2M [00:00<?, ?B/s]
# v2/train-00002-of-00003.parquet:   0%|          | 0.00/23.3M [00:00<?, ?B/s]
# v2/test-00000-of-00001.parquet:   0%|          | 0.00/1.03M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/298888 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/4941 [00:00<?, ? examples/s]
# [Sampler] ===== Stratified Sampling Report =====
# category  hard  available  quota  sampled
#      CRD False     127468   2400     2400
#      NPA False      32238   2400     2400
#      STA False      85604   2400     2400
#     TEMP False      41517   2400     2400
#       TH False      12061   2400     2400
# [Sampler] Total sampled: 30000
# [Sampler] ============================================================
# [Dataset] Train: 30000 | Test: 500
#
# ======================================================================
# PHASE 2: QLoRA + Prefix Tuning with Stratified Sampling
# Base model : meta-llama/Llama-3.1-8B-Instruct
# Train size : 30000 (after sampling)
# Test size  : 500
# ======================================================================
#
# ======================================================================
# Method: QLORA_R32
# ======================================================================
#
# [QLoRA] Loading base model (4-bit)...
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/296 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/855 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/184 [00:00<?, ?B/s]
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_deprecation.py:100: FutureWarning: Deprecated argument(s) used in '__init__': dataset_text_field. Will not be supported from version '1.0.0'.
#
# Deprecated positional argument(s) used in SFTTrainer, please use the SFTConfig to set these arguments instead.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/trl/trainer/sft_trainer.py:318: UserWarning: You passed a `dataset_text_field` argument to the SFTTrainer, the value you passed will override the one in the `SFTConfig`.
#   warnings.warn(
# Map:   0%|          | 0/30000 [00:00<?, ? examples/s]
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`.
# [QLoRA] Training on 30000 samples...
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:1181: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. Starting in PyTorch 2.9, calling checkpoint without use_reentrant will raise an exception. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
#     <div>
#
#       <progress value='7500' max='7500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [7500/7500 7:42:03, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>2.038700</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.680000</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.642700</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.617000</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>1.617700</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.601100</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>1.569800</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.557800</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>1.539300</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.533100</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>1.493700</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>1.500900</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>1.459700</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>1.459200</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>1.414200</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>1.405900</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>1.399200</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>1.324900</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>1.335800</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>1.321700</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>1.266700</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>1.243300</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>1.226800</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>1.210800</td>
#     </tr>
#     <tr>
#       <td>1250</td>
#       <td>1.180200</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>1.131100</td>
#     </tr>
#     <tr>
#       <td>1350</td>
#       <td>1.121900</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>1.113200</td>
#     </tr>
#     <tr>
#       <td>1450</td>
#       <td>1.097200</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>1.045000</td>
#     </tr>
#     <tr>
#       <td>1550</td>
#       <td>1.003600</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.992700</td>
#     </tr>
#     <tr>
#       <td>1650</td>
#       <td>1.004400</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.928900</td>
#     </tr>
#     <tr>
#       <td>1750</td>
#       <td>0.947100</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.914500</td>
#     </tr>
#     <tr>
#       <td>1850</td>
#       <td>0.853600</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.733600</td>
#     </tr>
#     <tr>
#       <td>1950</td>
#       <td>0.623800</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.605200</td>
#     </tr>
#     <tr>
#       <td>2050</td>
#       <td>0.585700</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.606300</td>
#     </tr>
#     <tr>
#       <td>2150</td>
#       <td>0.590000</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>0.589800</td>
#     </tr>
#     <tr>
#       <td>2250</td>
#       <td>0.577300</td>
#     </tr>
#     <tr>
#       <td>2300</td>
#       <td>0.587000</td>
#     </tr>
#     <tr>
#       <td>2350</td>
#       <td>0.574600</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.539600</td>
#     </tr>
#     <tr>
#       <td>2450</td>
#       <td>0.544300</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.518300</td>
#     </tr>
#     <tr>
#       <td>2550</td>
#       <td>0.514600</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>0.481800</td>
#     </tr>
#     <tr>
#       <td>2650</td>
#       <td>0.521600</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>0.523100</td>
#     </tr>
#     <tr>
#       <td>2750</td>
#       <td>0.496000</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>0.481700</td>
#     </tr>
#     <tr>
#       <td>2850</td>
#       <td>0.461900</td>
#     </tr>
#     <tr>
#       <td>2900</td>
#       <td>0.481700</td>
#     </tr>
#     <tr>
#       <td>2950</td>
#       <td>0.455800</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.433500</td>
#     </tr>
#     <tr>
#       <td>3050</td>
#       <td>0.411500</td>
#     </tr>
#     <tr>
#       <td>3100</td>
#       <td>0.437600</td>
#     </tr>
#     <tr>
#       <td>3150</td>
#       <td>0.443100</td>
#     </tr>
#     <tr>
#       <td>3200</td>
#       <td>0.425900</td>
#     </tr>
#     <tr>
#       <td>3250</td>
#       <td>0.385200</td>
#     </tr>
#     <tr>
#       <td>3300</td>
#       <td>0.417400</td>
#     </tr>
#     <tr>
#       <td>3350</td>
#       <td>0.415400</td>
#     </tr>
#     <tr>
#       <td>3400</td>
#       <td>0.400100</td>
#     </tr>
#     <tr>
#       <td>3450</td>
#       <td>0.385600</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.381000</td>
#     </tr>
#     <tr>
#       <td>3550</td>
#       <td>0.369100</td>
#     </tr>
#     <tr>
#       <td>3600</td>
#       <td>0.363000</td>
#     </tr>
#     <tr>
#       <td>3650</td>
#       <td>0.342600</td>
#     </tr>
#     <tr>
#       <td>3700</td>
#       <td>0.342800</td>
#     </tr>
#     <tr>
#       <td>3750</td>
#       <td>0.349400</td>
#     </tr>
#     <tr>
#       <td>3800</td>
#       <td>0.210000</td>
#     </tr>
#     <tr>
#       <td>3850</td>
#       <td>0.224300</td>
#     </tr>
#     <tr>
#       <td>3900</td>
#       <td>0.213800</td>
#     </tr>
#     <tr>
#       <td>3950</td>
#       <td>0.226100</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.211500</td>
#     </tr>
#     <tr>
#       <td>4050</td>
#       <td>0.222200</td>
#     </tr>
#     <tr>
#       <td>4100</td>
#       <td>0.225700</td>
#     </tr>
#     <tr>
#       <td>4150</td>
#       <td>0.223700</td>
#     </tr>
#     <tr>
#       <td>4200</td>
#       <td>0.218500</td>
#     </tr>
#     <tr>
#       <td>4250</td>
#       <td>0.221900</td>
#     </tr>
#     <tr>
#       <td>4300</td>
#       <td>0.219200</td>
#     </tr>
#     <tr>
#       <td>4350</td>
#       <td>0.214500</td>
#     </tr>
#     <tr>
#       <td>4400</td>
#       <td>0.210800</td>
#     </tr>
#     <tr>
#       <td>4450</td>
#       <td>0.214600</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.215100</td>
#     </tr>
#     <tr>
#       <td>4550</td>
#       <td>0.206000</td>
#     </tr>
#     <tr>
#       <td>4600</td>
#       <td>0.211900</td>
#     </tr>
#     <tr>
#       <td>4650</td>
#       <td>0.202300</td>
#     </tr>
#     <tr>
#       <td>4700</td>
#       <td>0.210900</td>
#     </tr>
#     <tr>
#       <td>4750</td>
#       <td>0.206000</td>
#     </tr>
#     <tr>
#       <td>4800</td>
#       <td>0.205600</td>
#     </tr>
#     <tr>
#       <td>4850</td>
#       <td>0.197800</td>
#     </tr>
#     <tr>
#       <td>4900</td>
#       <td>0.207700</td>
#     </tr>
#     <tr>
#       <td>4950</td>
#       <td>0.189900</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.195700</td>
#     </tr>
#     <tr>
#       <td>5050</td>
#       <td>0.192600</td>
#     </tr>
#     <tr>
#       <td>5100</td>
#       <td>0.191700</td>
#     </tr>
#     <tr>
#       <td>5150</td>
#       <td>0.196400</td>
#     </tr>
#     <tr>
#       <td>5200</td>
#       <td>0.189200</td>
#     </tr>
#     <tr>
#       <td>5250</td>
#       <td>0.188400</td>
#     </tr>
#     <tr>
#       <td>5300</td>
#       <td>0.198800</td>
#     </tr>
#     <tr>
#       <td>5350</td>
#       <td>0.192500</td>
#     </tr>
#     <tr>
#       <td>5400</td>
#       <td>0.178700</td>
#     </tr>
#     <tr>
#       <td>5450</td>
#       <td>0.183400</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.173100</td>
#     </tr>
#     <tr>
#       <td>5550</td>
#       <td>0.180300</td>
#     </tr>
#     <tr>
#       <td>5600</td>
#       <td>0.192500</td>
#     </tr>
#     <tr>
#       <td>5650</td>
#       <td>0.152600</td>
#     </tr>
#     <tr>
#       <td>5700</td>
#       <td>0.120700</td>
#     </tr>
#     <tr>
#       <td>5750</td>
#       <td>0.119600</td>
#     </tr>
#     <tr>
#       <td>5800</td>
#       <td>0.118700</td>
#     </tr>
#     <tr>
#       <td>5850</td>
#       <td>0.123000</td>
#     </tr>
#     <tr>
#       <td>5900</td>
#       <td>0.117600</td>
#     </tr>
#     <tr>
#       <td>5950</td>
#       <td>0.117500</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.120900</td>
#     </tr>
#     <tr>
#       <td>6050</td>
#       <td>0.123900</td>
#     </tr>
#     <tr>
#       <td>6100</td>
#       <td>0.121000</td>
#     <
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:1181: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. Starting in PyTorch 2.9, calling checkpoint without use_reentrant will raise an exception. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:1181: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. Starting in PyTorch 2.9, calling checkpoint without use_reentrant will raise an exception. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:1181: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. Starting in PyTorch 2.9, calling checkpoint without use_reentrant will raise an exception. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:1181: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. Starting in PyTorch 2.9, calling checkpoint without use_reentrant will raise an exception. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:1181: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. Starting in PyTorch 2.9, calling checkpoint without use_reentrant will raise an exception. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:1181: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. Starting in PyTorch 2.9, calling checkpoint without use_reentrant will raise an exception. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:1181: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. Starting in PyTorch 2.9, calling checkpoint without use_reentrant will raise an exception. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:1181: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. Starting in PyTorch 2.9, calling checkpoint without use_reentrant will raise an exception. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:1181: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. Starting in PyTorch 2.9, calling checkpoint without use_reentrant will raise an exception. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:1181: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. Starting in PyTorch 2.9, calling checkpoint without use_reentrant will raise an exception. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:1181: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. Starting in PyTorch 2.9, calling checkpoint without use_reentrant will raise an exception. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:1181: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. Starting in PyTorch 2.9, calling checkpoint without use_reentrant will raise an exception. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:1181: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. Starting in PyTorch 2.9, calling checkpoint without use_reentrant will raise an exception. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:1181: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. Starting in PyTorch 2.9, calling checkpoint without use_reentrant will raise an exception. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:1181: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. Starting in PyTorch 2.9, calling checkpoint without use_reentrant will raise an exception. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:1181: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. Starting in PyTorch 2.9, calling checkpoint without use_reentrant will raise an exception. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:1181: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. Starting in PyTorch 2.9, calling checkpoint without use_reentrant will raise an exception. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:1181: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. Starting in PyTorch 2.9, calling checkpoint without use_reentrant will raise an exception. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:1181: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. Starting in PyTorch 2.9, calling checkpoint without use_reentrant will raise an exception. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:1181: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. Starting in PyTorch 2.9, calling checkpoint without use_reentrant will raise an exception. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:1181: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. Starting in PyTorch 2.9, calling checkpoint without use_reentrant will raise an exception. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:1181: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. Starting in PyTorch 2.9, calling checkpoint without use_reentrant will raise an exception. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:1181: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. Starting in PyTorch 2.9, calling checkpoint without use_reentrant will raise an exception. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:1181: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. Starting in PyTorch 2.9, calling checkpoint without use_reentrant will raise an exception. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:1181: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. Starting in PyTorch 2.9, calling checkpoint without use_reentrant will raise an exception. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:1181: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. Starting in PyTorch 2.9, calling checkpoint without use_reentrant will raise an exception. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:1181: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. Starting in PyTorch 2.9, calling checkpoint without use_reentrant will raise an exception. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:1181: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. Starting in PyTorch 2.9, calling checkpoint without use_reentrant will raise an exception. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:1181: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. Starting in PyTorch 2.9, calling checkpoint without use_reentrant will raise an exception. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:1181: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. Starting in PyTorch 2.9, calling checkpoint without use_reentrant will raise an exception. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:1181: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. Starting in PyTorch 2.9, calling checkpoint without use_reentrant will raise an exception. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:1181: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. Starting in PyTorch 2.9, calling checkpoint without use_reentrant will raise an exception. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:1181: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. Starting in PyTorch 2.9, calling checkpoint without use_reentrant will raise an exception. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:1181: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. Starting in PyTorch 2.9, calling checkpoint without use_reentrant will raise an exception. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:1181: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. Starting in PyTorch 2.9, calling checkpoint without use_reentrant will raise an exception. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:1181: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. Starting in PyTorch 2.9, calling checkpoint without use_reentrant will raise an exception. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:1181: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. Starting in PyTorch 2.9, calling checkpoint without use_reentrant will raise an exception. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# [QLoRA] Saved → /content/drive/MyDrive/Datasci_266_NLP/Final Project/CinePile_Phase2/qlora_r32
# Eval qlora_r32:   0%|          | 0/500 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# Starting from v4.46, the `logits` model output will have the same type as the model (except at train time, where it will always be FP32)
# Eval qlora_r32:   0%|          | 0/500 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_3804/768125029.py in <cell line: 0>()
#     681
#     682     runner = Phase2Runner(cfg, tracker=tracker)
# --> 683     runner.run()
#
# /tmp/ipykernel_3804/768125029.py in run(self)
#     608             trainer.train(self.dataset.train_data)
#     609
# --> 610             metrics = self.evaluator.evaluate(
#     611                 trainer.model,
#     612                 trainer.tokenizer,
#
# /tmp/ipykernel_3804/768125029.py in evaluate(self, model, tokenizer, test_data, method_name)
#     324         records = []
#     325         for s in tqdm(test_data, desc=f"Eval {method_name}"):
# --> 326             pred = self._predict(model, tokenizer, s)
#     327             records.append({
#     328                 "pred":              pred,
#
# /tmp/ipykernel_3804/768125029.py in _predict(self, model, tokenizer, sample)
#     344
#     345         with torch.no_grad():
# --> 346             outputs = model.generate(
#     347                 **inputs,
#     348                 max_new_tokens=self.cfg.max_new_tokens,
#
# /usr/local/lib/python3.12/dist-packages/peft/peft_model.py in generate(self, *args, **kwargs)
#    1489                 with self._enable_peft_forward_hooks(*args, **kwargs):
#    1490                     kwargs = {k: v for k, v in kwargs.items() if k not in self.special_peft_forward_args}
# -> 1491                     outputs = self.base_model.generate(*args, **kwargs)
#    1492             else:
#    1493                 outputs = self.base_model.generate(**kwargs)
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     122         # pyrefly: ignore [bad-context-manager]
#     123         with ctx_factory():
# --> 124             return func(*args, **kwargs)
#     125
#     126     return decorate_context
#
# /usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    2045
#    2046             # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2047             result = self._sample(
#    2048                 input_ids,
#    2049                 logits_processor=prepared_logits_processor,
#
# /usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py in _sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    3005
#    3006             # forward pass to get next token
# -> 3007             outputs = self(**model_inputs, return_dict=True)
#    3008
#    3009             if synced_gpus and this_peer_finished:
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, num_logits_to_keep)
#    1212             # Only compute necessary logits, and do not upcast them to float if we are not computing the loss
#    1213             # TODO: remove the float() operation in v4.46
# -> 1214             logits = self.lm_head(hidden_states[:, -num_logits_to_keep:, :]).float()
#    1215
#    1216         loss = None
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     132         Runs the forward pass.
#     133         """
# --> 134         return F.linear(input, self.weight, self.bias)
#     135
#     136     def extra_repr(self) -> str:
#
# RuntimeError: expected scalar type Float but found BFloat16

# %%
# ============================================================
# Phase 2: QLoRA + Prefix Tuning on CinePile (with Stratified Sampling & Checkpoints)
# Requirements:
#   pip install transformers datasets accelerate bitsandbytes peft trl
# ============================================================

import os
import gc
from dataclasses import dataclass, field
from typing import Optional, List, Dict
from datetime import datetime
from collections import defaultdict

import torch
import pandas as pd
from datasets import load_dataset, Dataset
from tqdm import tqdm

from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    BitsAndBytesConfig,
)
from peft import (
    LoraConfig,
    PrefixTuningConfig,
    get_peft_model,
    TaskType,
)
from trl import SFTTrainer, SFTConfig


# ============================================================
# 1. 配置
# ============================================================
@dataclass
class Phase2Config:
    # 数据集
    dataset_name: str          = "tomg-group-umd/cinepile"
    train_split: str           = "train"
    test_split: str            = "test"

    # 分层抽样（None = 用完整 split）
    max_train_samples: Optional[int] = 30000   # e.g. 从 ~30 万中抽 3 万
    max_test_samples: Optional[int]  = 500     # 测试集可截断或用 full

    # hard 样本在分层抽样中的额外倍率（>1 表示更偏向抽 hard）
    hard_oversample_ratio: float     = 1.5

    # 模型
    base_model_id: str         = "meta-llama/Llama-3.1-8B-Instruct"

    # 输入长度
    max_scene_length: int      = 1200   ### Change from 1000 to 1200 (allow more scene context)
    max_seq_length: int        = 1536   ### Change from 1024 to 1536 (better reasoning window)

    # 通用训练参数
    num_train_epochs: int      = 4      ### Change from 3 to 4 (LoRA rarely overfits, improves learning)
    per_device_train_batch_size: int = 4   ### Change from 4 to 1 (T4 VRAM stability)
    gradient_accumulation_steps: int = 4  ### Change from 4 to 16 (keep effective batch size ≈16)
    learning_rate: float       = 2e-4
    warmup_ratio: float        = 0.05
    lr_scheduler_type: str     = "cosine"

    bf16: bool                 = True   ### Change to True for A100
    fp16: bool                 = False

    logging_steps: int         = 50

    # checkpoint & 输出
    save_steps: int            = 200
    save_total_limit: int      = 3
    output_base_dir: str       = "./phase2_outputs"
    output_csv: str            = "phase2_results.csv"

    # QLoRA
    lora_r: int                = 32 ### Consider a higher value if the model is struggling to capture the complexity
    lora_alpha: int            = 64
    lora_dropout: float        = 0.0 ### Since we have big example sizes (30000), maybe try 0
    lora_target_modules: List[str] = field(default_factory=lambda: [
        "q_proj", "k_proj", "v_proj", "o_proj",
        "gate_proj", "up_proj", "down_proj",
    ]) ### Recommend all 7 layers, but might also try less

    # Prefix Tuning
    prefix_num_virtual_tokens: int = 20

    # 评估生成长度
    max_new_tokens: int        = 2

    # 类别映射
    category_map: Dict[str, str] = field(default_factory=lambda: {
        "TEMP": "Temporal",
        "CRD":  "Character and",
        "NPA":  "Narrative and",
        "STA":  "Setting and",
        "TH":   "Theme Exploration",
    })


# ============================================================
# 2. Stratified Sampler（按类别 × hard 分层抽样）
# ============================================================
class StratifiedSampler:
    def __init__(self, cfg: Phase2Config):
        self.cfg = cfg

    def sample(self, data: list) -> list:
        if self.cfg.max_train_samples is None:
            print(f"[Sampler] Using full train split: {len(data)} samples")
            return data

        target = self.cfg.max_train_samples

        # 按 (category_key, hard) 分组
        groups = defaultdict(list)
        for s in data:
            cat  = self._get_category_key(s["question_category"])
            hard = bool(s["hard_split"])
            groups[(cat, hard)].append(s)

        n_categories = len(set(k[0] for k in groups))
        # 理论 strata = 每个类别 × hard/easy
        base_quota = target / (n_categories * (1 + self.cfg.hard_oversample_ratio))
        easy_q     = base_quota
        hard_q     = base_quota * self.cfg.hard_oversample_ratio

        sampled = []
        report  = []

        import random
        random.seed(42) # same seed using in ReFT part

        for (cat, hard), group in sorted(groups.items()):
            quota  = int(hard_q if hard else easy_q)
            n_take = min(quota, len(group))
            taken  = random.sample(group, n_take)
            sampled.extend(taken)
            report.append({
                "category":  cat,
                "hard":      hard,
                "available": len(group),
                "quota":     quota,
                "sampled":   n_take,
            })

        # 若仍不足 target，从剩余中补齐
        if len(sampled) < target:
            sampled_ids = set(id(s) for s in sampled)
            remaining   = [s for s in data if id(s) not in sampled_ids]
            extra = random.sample(
                remaining, min(target - len(sampled), len(remaining))
            )
            sampled.extend(extra)

        self._print_report(report, len(sampled))
        return sampled

    def _get_category_key(self, cat_str: str) -> str:
        for abbr, kw in self.cfg.category_map.items():
            if kw.lower() in cat_str.lower():
                return abbr
        return "OTHER"

    @staticmethod
    def _print_report(report: list, total_sampled: int):
        df = pd.DataFrame(report)
        print("\n[Sampler] ===== Stratified Sampling Report =====")
        print(df.to_string(index=False))
        print(f"[Sampler] Total sampled: {total_sampled}")
        print("[Sampler] " + "=" * 60)


# ============================================================
# 3. ExperimentTracker（记录每次实验参数 + 结果）
# ============================================================
class ExperimentTracker:
    def __init__(self, log_path: str = "./phase2_experiments_log.csv"):
        self.log_path = log_path

    def log(self, method_name: str, cfg: Phase2Config, metrics: dict):
        record = {
            "timestamp":           datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
            "method":              method_name,
            "base_model":          cfg.base_model_id.split("/")[-1],
            "max_train_samples":   cfg.max_train_samples if cfg.max_train_samples else "full",
            "max_test_samples":    cfg.max_test_samples  if cfg.max_test_samples  else "full",
            "hard_oversample":     cfg.hard_oversample_ratio,
            "num_train_epochs":    cfg.num_train_epochs,
            "lora_r":              cfg.lora_r,
            "prefix_tokens":       cfg.prefix_num_virtual_tokens,
            "learning_rate":       cfg.learning_rate,
            "batch_size":          cfg.per_device_train_batch_size,
            "grad_accum":          cfg.gradient_accumulation_steps,
            # metrics
            "Overall": metrics.get("Overall"),
            "TEMP":    metrics.get("TEMP"),
            "CRD":     metrics.get("CRD"),
            "NPA":     metrics.get("NPA"),
            "STA":     metrics.get("STA"),
            "TH":      metrics.get("TH"),
            "Hard":    metrics.get("Hard"),
            "n_test":  metrics.get("Overall_n"),
            "n_TEMP":  metrics.get("TEMP_n"),
            "n_CRD":   metrics.get("CRD_n"),
            "n_NPA":   metrics.get("NPA_n"),
            "n_STA":   metrics.get("STA_n"),
            "n_TH":    metrics.get("TH_n"),
            "n_Hard":  metrics.get("Hard_n"),
        }
        df_new = pd.DataFrame([record])
        if os.path.exists(self.log_path):
            df_old = pd.read_csv(self.log_path)
            df_all = pd.concat([df_old, df_new], ignore_index=True)
        else:
            df_all = df_new
        df_all.to_csv(self.log_path, index=False)
        print(f"[Tracker] Logged {method_name} → {self.log_path}")
        return df_all


# ============================================================
# 4. 数据加载 & 预处理
# ============================================================
class CinePileDataset:
    LETTERS = ["A", "B", "C", "D", "E"]

    def __init__(self, cfg: Phase2Config):
        self.cfg = cfg
        self.train_data, self.test_data = self._load_all()
        print(f"[Dataset] Train: {len(self.train_data)} | Test: {len(self.test_data)}")

    @classmethod
    def _answer_text_to_letter(cls, answer_text: str, choices: list) -> str:
        for i, c in enumerate(choices):
            if answer_text.strip() == c.strip():
                return cls.LETTERS[i]
        for i, c in enumerate(choices):
            if answer_text.strip() in c or c.strip() in answer_text:
                return cls.LETTERS[i]
        return "A"

    @staticmethod
    def _normalize_hard_split(raw) -> bool:
        if isinstance(raw, bool):
            return raw
        return str(raw).strip().lower() == "true"

    def _load_split(self, split: str) -> list:
        raw = load_dataset(self.cfg.dataset_name, split=split)
        samples = []
        for ex in raw:
            letter = self._answer_text_to_letter(ex["answer_key"], ex["choices"])
            samples.append({
                "movie_scene":       ex["movie_scene"],
                "question":          ex["question"],
                "choices":           ex["choices"],
                "answer_key":        letter,
                "question_category": ex["question_category"],
                "hard_split":        self._normalize_hard_split(ex["hard_split"]),
            })
        return samples

    def _load_all(self):
        train_raw = self._load_split(self.cfg.train_split)
        test_raw  = self._load_split(self.cfg.test_split)

        # 训练集分层抽样
        sampler    = StratifiedSampler(self.cfg)
        train_data = sampler.sample(train_raw)

        # 测试集截断
        if self.cfg.max_test_samples:
            test_data = test_raw[:self.cfg.max_test_samples]
        else:
            test_data = test_raw

        return train_data, test_data


# ============================================================
# 5. Prompt Builder & Evaluator
# ============================================================
class PromptBuilder:
    @staticmethod
    def build_train_prompt(sample: dict, max_scene_length: int) -> str:
        scene   = sample["movie_scene"][:max_scene_length]
        options = "\n".join(
            f"{chr(65+i)}. {c}" for i, c in enumerate(sample["choices"])
        )
        return (
            "You are watching a movie. Based on the scene description, "
            "answer the multiple choice question.\n\n"
            f"Scene: {scene}\n\n"
            f"Question: {sample['question']}\n\n"
            f"Think briefly about the scene before choosing the answer.\n\n"
            f"Options:\n{options}\n\n"
            f"Answer (A/B/C/D/E): {sample['answer_key']}"
        )

    @staticmethod
    def build_inference_prompt(sample: dict, max_scene_length: int) -> str:
        scene   = sample["movie_scene"][:max_scene_length]
        options = "\n".join(
            f"{chr(65+i)}. {c}" for i, c in enumerate(sample["choices"])
        )
        return (
            "You are watching a movie. Based on the scene description, "
            "answer the multiple choice question.\n\n"
            f"Scene: {scene}\n\n"
            f"Question: {sample['question']}\n\n"
            f"Think briefly about the scene before choosing the answer.\n\n"
            f"Options:\n{options}\n\n"
            "Answer (A/B/C/D/E):"
        )


class Evaluator:
    def __init__(self, cfg: Phase2Config):
        self.cfg = cfg

    def evaluate(self, model, tokenizer, test_data: list, method_name: str) -> dict:
        model.eval()
        records = []
        for s in tqdm(test_data, desc=f"Eval {method_name}"):
            pred = self._predict(model, tokenizer, s)
            records.append({
                "pred":              pred,
                "label":             s["answer_key"],
                "question_category": s["question_category"],
                "hard_split":        s["hard_split"],
            })
        df = pd.DataFrame(records)
        return self._compute_metrics(df)

    def _predict(self, model, tokenizer, sample: dict) -> str:
        prompt = PromptBuilder.build_inference_prompt(sample, self.cfg.max_scene_length)
        inputs = tokenizer(
            prompt,
            return_tensors="pt",
            truncation=True,
            max_length=self.cfg.max_seq_length,
        ).to(model.device)

        inputs = {k: v.to(model.device) for k, v in inputs.items()} ## Add this line

        # model = model.to(torch.bfloat16) ## To correct expected scalar type Float but found BFloat16 error

        with torch.no_grad():
            outputs = model.generate(
                **inputs,
                max_new_tokens=self.cfg.max_new_tokens,
                do_sample=False,
                pad_token_id=tokenizer.eos_token_id,
            )
        decoded = tokenizer.decode(
            outputs[0][inputs["input_ids"].shape[1]:],
            skip_special_tokens=True,
        ).strip().upper()

        import re

        match = re.search(r"\b([A-E])\b", decoded)
        if match:
            return match.group(1)

        return "A"

    def _compute_metrics(self, df: pd.DataFrame) -> dict:
        correct = df["pred"] == df["label"]
        metrics = {
            "Overall":   correct.mean(),
            "Overall_n": len(df),
        }
        for abbr, keyword in self.cfg.category_map.items():
            mask = df["question_category"].str.contains(keyword, case=False, na=False)
            n    = int(mask.sum())
            metrics[abbr]        = correct[mask].mean() if n > 0 else None
            metrics[f"{abbr}_n"] = n

        hard_mask = df["hard_split"] == True
        n_hard    = int(hard_mask.sum())
        metrics["Hard"]   = correct[hard_mask].mean() if n_hard > 0 else None
        metrics["Hard_n"] = n_hard
        return metrics


# ============================================================
# 6. 基类 Trainer
# ============================================================
class BasePEFTTrainer:
    def __init__(self, cfg: Phase2Config, method_name: str):
        self.cfg         = cfg
        self.method_name = method_name
        self.model       = None
        self.tokenizer   = None

    def _output_dir(self) -> str:
        path = os.path.join(self.cfg.output_base_dir, self.method_name)
        os.makedirs(path, exist_ok=True)
        return path

    def _make_hf_dataset(self, data: list) -> Dataset:
        return Dataset.from_list([
            {"text": PromptBuilder.build_train_prompt(s, self.cfg.max_scene_length)}
            for s in data
        ])

    def free_memory(self):
        if self.model is not None:
            del self.model
        if self.tokenizer is not None:
            del self.tokenizer
        self.model = None
        self.tokenizer = None
        gc.collect()
        torch.cuda.empty_cache()
        print(f"[Memory] Freed for {self.method_name}")


# ============================================================
# 7. QLoRA Trainer（含 checkpoint）
# ============================================================
class QLoRATrainer(BasePEFTTrainer):
    def __init__(self, cfg: Phase2Config):
        super().__init__(cfg, method_name=f"qlora_r{cfg.lora_r}")

    def _load_base_model_4bit(self):

        bnb_config = BitsAndBytesConfig(
            load_in_4bit              = True,
            bnb_4bit_use_double_quant = True,
            bnb_4bit_quant_type       = "nf4",

            bnb_4bit_compute_dtype=torch.bfloat16

            ### Recover bfloat16 for A100

        )

        tokenizer = AutoTokenizer.from_pretrained(self.cfg.base_model_id)

        tokenizer.pad_token    = tokenizer.eos_token
        tokenizer.padding_side = "right"

        model = AutoModelForCausalLM.from_pretrained(
            self.cfg.base_model_id,
            quantization_config=bnb_config,
            device_map="auto",
        )

        return model, tokenizer

    def train(self, train_data: list):
        print(f"\n[QLoRA] Loading base model (4-bit)...")
        model, tokenizer = self._load_base_model_4bit()

        lora_config = LoraConfig(
            r              = self.cfg.lora_r,
            lora_alpha     = self.cfg.lora_alpha,
            lora_dropout   = self.cfg.lora_dropout,
            target_modules = self.cfg.lora_target_modules,
            bias           = "none",
            task_type      = TaskType.CAUSAL_LM,
        )

        args = SFTConfig(
            output_dir                  = self._output_dir(),
            num_train_epochs            = self.cfg.num_train_epochs,
            per_device_train_batch_size = self.cfg.per_device_train_batch_size,
            gradient_accumulation_steps = self.cfg.gradient_accumulation_steps,
            learning_rate               = self.cfg.learning_rate,
            warmup_ratio                = self.cfg.warmup_ratio,
            lr_scheduler_type           = self.cfg.lr_scheduler_type,

            bf16=self.cfg.bf16,
            fp16=self.cfg.fp16,
            ### Added fp16=True support for T4 GPU

            logging_steps               = self.cfg.logging_steps,

            save_strategy               = "steps",
            save_steps                  = self.cfg.save_steps,
            save_total_limit            = self.cfg.save_total_limit,
            max_seq_length              = self.cfg.max_seq_length, # Move to SFTTrainer
            # dataset_text_field          = "text",
            report_to                   = "none",
            gradient_checkpointing      = True,
            optim                       = "paged_adamw_8bit",
        )

        hf_dataset = self._make_hf_dataset(train_data)
        trainer = SFTTrainer(
            model         = model,
            args          = args,
            train_dataset = hf_dataset,
            peft_config   = lora_config,
            tokenizer     = tokenizer,


            dataset_text_field = 'text', # Improve GPU utilization
            packing       = False, # Improve GPU utilization

        )

        print(f"[QLoRA] Training on {len(train_data)} samples...")
        trainer.train()
        trainer.save_model(self._output_dir())
        tokenizer.save_pretrained(self._output_dir())
        print(f"[QLoRA] Saved → {self._output_dir()}")

        self.model     = trainer.model
        self.tokenizer = tokenizer


# ============================================================
# 8. Prefix Tuning Trainer（含 checkpoint）
# ============================================================
class PrefixTuningTrainer(BasePEFTTrainer):
    def __init__(self, cfg: Phase2Config):
        super().__init__(cfg, method_name=f"prefix_vt{cfg.prefix_num_virtual_tokens}")

    def _load_base_model_bf16(self):
        tokenizer = AutoTokenizer.from_pretrained(self.cfg.base_model_id)
        tokenizer.pad_token    = tokenizer.eos_token
        tokenizer.padding_side = "right"
        model = AutoModelForCausalLM.from_pretrained(
            self.cfg.base_model_id,
            torch_dtype=torch.bfloat16,
            device_map="auto",
        )
        return model, tokenizer

    def train(self, train_data: list):
        print(f"\n[Prefix] Loading base model (bf16)...")
        model, tokenizer = self._load_base_model_bf16()

        prefix_config = PrefixTuningConfig(
            task_type          = TaskType.CAUSAL_LM,
            num_virtual_tokens = self.cfg.prefix_num_virtual_tokens,
            prefix_projection  = True,
        )
        model = get_peft_model(model, prefix_config)
        model.print_trainable_parameters()

        args = SFTConfig(
            output_dir                  = self._output_dir(),
            num_train_epochs            = self.cfg.num_train_epochs,
            per_device_train_batch_size = self.cfg.per_device_train_batch_size,
            gradient_accumulation_steps = self.cfg.gradient_accumulation_steps,
            learning_rate               = 1e-3,   # Prefix 一般 lr 更大
            warmup_ratio                = self.cfg.warmup_ratio,
            lr_scheduler_type           = self.cfg.lr_scheduler_type,
            bf16                        = self.cfg.bf16,
            logging_steps               = self.cfg.logging_steps,
            save_strategy               = "steps",
            save_steps                  = self.cfg.save_steps,
            save_total_limit            = self.cfg.save_total_limit,
            max_seq_length              = self.cfg.max_seq_length,
            dataset_text_field          = "text",
            report_to                   = "none",
            gradient_checkpointing      = False,
        )

        hf_dataset = self._make_hf_dataset(train_data)
        trainer = SFTTrainer(
            model         = model,
            args          = args,
            train_dataset = hf_dataset,
            tokenizer     = tokenizer,
        )

        print(f"[Prefix] Training on {len(train_data)} samples...")
        trainer.train()
        trainer.save_model(self._output_dir())
        tokenizer.save_pretrained(self._output_dir())
        print(f"[Prefix] Saved → {self._output_dir()}")

        self.model     = trainer.model
        self.tokenizer = tokenizer


# ============================================================
# 9. Phase2 Runner
# ============================================================
class Phase2Runner:
    def __init__(self, cfg: Phase2Config, tracker: Optional[ExperimentTracker] = None):
        self.cfg      = cfg
        self.dataset  = CinePileDataset(cfg)
        self.evaluator = Evaluator(cfg)
        self.tracker  = tracker
        self.results  = {}

        self.trainers = [
            QLoRATrainer(cfg),
            # PrefixTuningTrainer(cfg),
        ]

    def run(self):
        print("\n" + "=" * 70)
        print("PHASE 2: QLoRA + Prefix Tuning with Stratified Sampling")
        print(f"Base model : {self.cfg.base_model_id}")
        print(f"Train size : {len(self.dataset.train_data)} (after sampling)")
        print(f"Test size  : {len(self.dataset.test_data)}")
        print("=" * 70)

        for trainer in self.trainers:
            print("\n" + "=" * 70)
            print(f"Method: {trainer.method_name.upper()}")
            print("=" * 70)

            trainer.train(self.dataset.train_data)

            metrics = self.evaluator.evaluate(
                trainer.model,
                trainer.tokenizer,
                self.dataset.test_data,
                trainer.method_name,
            )
            self.results[trainer.method_name] = metrics

            hard_str = (f"{metrics['Hard']:.2%}"
                        if metrics.get("Hard") is not None else "N/A")
            print(f"[{trainer.method_name}] Overall: {metrics['Overall']:.2%} | Hard: {hard_str}")

            if self.tracker is not None:
                self.tracker.log(trainer.method_name, self.cfg, metrics)

            trainer.free_memory()

        self._display_and_save()

    def _display_and_save(self):
        display_cols = ["Overall", "TEMP", "CRD", "NPA", "STA", "TH", "Hard"]
        rows = []
        for method, metrics in self.results.items():
            row = {"Method": method}
            for col in display_cols:
                val = metrics.get(col)
                n   = metrics.get(f"{col}_n", metrics.get("Overall_n", ""))
                row[col] = f"{val:.1%}(n={n})" if val is not None else "N/A"
            rows.append(row)

        df = pd.DataFrame(rows)
        print("\n" + "=" * 70)
        print("PHASE 2 FINAL RESULTS — QLoRA + Prefix (Stratified 30k)")
        print("=" * 70)
        print(df.to_string(index=False))
        df.to_csv(self.cfg.output_csv, index=False)
        print(f"\n[Phase2] Saved table → {self.cfg.output_csv}")

# %%
if __name__ == "__main__":

    import transformers
    print("transformers:", transformers.__version__)

    from google.colab import drive
    drive.mount('/content/drive')

    PROJECT_DIR = "/content/drive/MyDrive/Datasci_266_NLP/Final Project/CinePile_Phase2"
    os.makedirs(PROJECT_DIR, exist_ok=True)

    # ============================================================
    # Config
    # ============================================================

    cfg = Phase2Config(
        base_model_id="meta-llama/Llama-3.1-8B-Instruct",

        max_train_samples=30000,
        max_test_samples=500,
        hard_oversample_ratio=1.5,

        num_train_epochs=4,
        per_device_train_batch_size=4,
        gradient_accumulation_steps=4,

        learning_rate=2e-4,

        output_base_dir=PROJECT_DIR,
        output_csv=os.path.join(PROJECT_DIR, "phase2_results.csv"),
    )

    tracker = ExperimentTracker(
        log_path=os.path.join(PROJECT_DIR, "phase2_experiments_log.csv")
    )

    # ============================================================
    # Reload Dataset
    # ============================================================

    dataset = CinePileDataset(cfg)

    # ============================================================
    # Reload QLoRA model from checkpoint
    # ============================================================

    model_path = os.path.join(PROJECT_DIR, "qlora_r32")

    print("\nReloading trained QLoRA model from:", model_path)

    tokenizer = AutoTokenizer.from_pretrained(model_path)

    model = AutoModelForCausalLM.from_pretrained(
        model_path,
        device_map="auto",
        torch_dtype=torch.bfloat16
    )

    # ============================================================
    # Evaluate
    # ============================================================

    evaluator = Evaluator(cfg)

    metrics = evaluator.evaluate(
        model,
        tokenizer,
        dataset.test_data,
        "qlora_r32"
    )

    print("\nEvaluation Results:")
    print(metrics)

    # ============================================================
    # Log experiment
    # ============================================================

    tracker.log("qlora_r32", cfg, metrics)

    print("\nExperiment finished.")
# Out:
# transformers: 4.45.2
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# README.md: 0.00B [00:00, ?B/s]
# v2/train-00000-of-00003.parquet:   0%|          | 0.00/21.9M [00:00<?, ?B/s]
# v2/train-00001-of-00003.parquet:   0%|          | 0.00/23.2M [00:00<?, ?B/s]
# v2/train-00002-of-00003.parquet:   0%|          | 0.00/23.3M [00:00<?, ?B/s]
# v2/test-00000-of-00001.parquet:   0%|          | 0.00/1.03M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/298888 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/4941 [00:00<?, ? examples/s]
# [Sampler] ===== Stratified Sampling Report =====
# category  hard  available  quota  sampled
#      CRD False     127468   2400     2400
#      NPA False      32238   2400     2400
#      STA False      85604   2400     2400
#     TEMP False      41517   2400     2400
#       TH False      12061   2400     2400
# [Sampler] Total sampled: 30000
# [Sampler] ============================================================
# [Dataset] Train: 30000 | Test: 500
#
# Reloading trained QLoRA model from: /content/drive/MyDrive/Datasci_266_NLP/Final Project/CinePile_Phase2/qlora_r32
# config.json:   0%|          | 0.00/855 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/184 [00:00<?, ?B/s]
# Eval qlora_r32:   0%|          | 0/500 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# Starting from v4.46, the `logits` model output will have the same type as the model (except at train time, where it will always be FP32)
# Eval qlora_r32: 100%|██████████| 500/500 [01:14<00:00,  6.69it/s]
# Evaluation Results:
# {'Overall': 0.636, 'Overall_n': 500, 'TEMP': 0.5303030303030303, 'TEMP_n': 66, 'CRD': 0.6588785046728972, 'CRD_n': 214, 'NPA': 0.625, 'NPA_n': 40, 'STA': 0.6878980891719745, 'STA_n': 157, 'TH': 0.391304347826087, 'TH_n': 23, 'Hard': 0.44545454545454544, 'Hard_n': 110}
# [Tracker] Logged qlora_r32 → /content/drive/MyDrive/Datasci_266_NLP/Final Project/CinePile_Phase2/phase2_experiments_log.csv
#
# Experiment finished.

# %%
# ============================================================
# 诊断代码：直接粘贴到 Colab 运行
# ============================================================
from datasets import load_dataset

dataset = load_dataset('tomg-group-umd/cinepile', split='test')

# Step 1: 查看原始字段
sample = dataset[0]
print("=== 所有字段名 ===")
print(list(sample.keys()))

print("\n=== answer_key 值和类型 ===")
print(repr(sample['answer_key']))
print(type(sample['answer_key']))

print("\n=== choices 值和类型 ===")
print(sample['choices'])
print(type(sample['choices'][0]))

print("\n=== question_category 示例 ===")
print(repr(sample['question_category']))

print("\n=== hard_split 值和类型 ===")
print(repr(sample['hard_split']))
print(type(sample['hard_split']))

# Step 2: 查看前5个样本的 answer_key
print("\n=== 前5个样本的 answer_key ===")
for i in range(5):
    print(f"  [{i}] answer_key = {repr(dataset[i]['answer_key'])}")

# Step 3: 查看所有 answer_key 的唯一值
print("\n=== answer_key 的所有唯一值（前100个样本）===")
unique_keys = set(dataset[i]['answer_key'] for i in range(100))
print(unique_keys)

# Step 4: 查看 question_category 的唯一值
print("\n=== question_category 的唯一值（前100个样本）===")
unique_cats = set(dataset[i]['question_category'] for i in range(100))
for c in sorted(unique_cats):
    print(f"  {repr(c)}")

# Step 5: 手动测试 DeBERTa predict 一次
print("\n=== DeBERTa 手动预测测试 ===")
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification

tokenizer = AutoTokenizer.from_pretrained('microsoft/deberta-v3-base')
model = AutoModelForSequenceClassification.from_pretrained(
    'microsoft/deberta-v3-base',
    num_labels=1
)
model.eval()

test_sample = dataset[0]
scores = []
scene_q = f"{test_sample['question']} {test_sample['movie_scene'][:512]}"

for i, choice in enumerate(test_sample['choices']):
    inputs = tokenizer(
        scene_q, choice,
        return_tensors='pt',
        truncation=True,
        max_length=512,
        padding=True
    )
    with torch.no_grad():
        logit = model(**inputs).logits.squeeze().item()
    scores.append(logit)
    print(f"  Choice {chr(65+i)}: logit = {logit:.4f}")

pred = chr(65 + scores.index(max(scores)))
label = test_sample['answer_key']
print(f"\n  Predicted: {pred}")
print(f"  Label:     {repr(label)}")
print(f"  Match:     {pred == label}")
# Out:
# === 所有字段名 ===
# ['movie_name', 'year', 'genre', 'yt_clip_title', 'yt_clip_link', 'movie_scene', 'subtitles', 'question', 'choices', 'answer_key', 'answer_key_position', 'question_category', 'hard_split', 'visual_reliance', 'videoID']
#
# === answer_key 值和类型 ===
# 'From anxiety to excitement'
# <class 'str'>
#
# === choices 值和类型 ===
# ['From despair to hope', 'From fear to acceptance', 'From confusion to understanding', 'From tension to panic', 'From anxiety to excitement']
# <class 'str'>
#
# === question_category 示例 ===
# 'Theme Exploration'
#
# === hard_split 值和类型 ===
# 'True'
# <class 'str'>
#
# === 前5个样本的 answer_key ===
#   [0] answer_key = 'From anxiety to excitement'
#   [1] answer_key = 'Suggests next steps'
#   [2] answer_key = 'The rough foliage'
#   [3] answer_key = 'She closes her eyes and focuses on staying calm without moving at all.'
#   [4] answer_key = 'Rough and dense'
#
# === answer_key 的所有唯一值（前100个样本）===
# {'Throw jerky to the dog, or it will injure people.', 'She visibly trembles but stays still.', 'Directly underneath', 'Gets out of bed', "On Arthur's bed", 'Suggests next steps', 'To see in the dark.', 'A cup of tea', 'They hear an aircraft approaching.', 'Night vision', 'To give up drinking', 'He yells for Reed.', 'He scrambles out of bed', 'Uncle Rudy', 'Picks a lock', 'It provides Arthur with a sense of hope and motivation', 'It forces them to stay hidden.', 'He creeps into an adjacent room.', 'The inability to see in the dark', 'It becomes calmer.', 'Waits for Reed', 'Jerky', 'Desperation', 'All of the above', 'The helicopter illuminates the foliage.', 'Hobson as a ghost', "The helicopter's presence forces them to stay hidden.", 'It illuminates the surrounding foliage.', "Arthur scrambles out of bed. Arthur looks at a wide-eyed man in brown. Hobson sits on Arthur's bed. Hobson fixes Arthur with his steely gaze. Arthur's eyes bulge.", 'It strengthens their bond', 'Rough and dense', 'They are close and supportive.', 'He is a butler', 'A dog running towards him', 'They become more cooperative', "The dog's aggression", 'They become more confident', 'From indifference to determination', 'He sweeps the camera around the living room.', 'His eyes bulge', 'He puts on a coat', 'To make them difficult to detect.', 'They are trying to remain undetected by the helicopter using thermal suits.', 'The sound of a helicopter', 'Cameraman', 'The rough foliage', 'In a cheap hotel', "The group stays down, the snake slithers between Jelena's thighs, the helicopter flies away.", 'He is a leader.', 'Reed', 'Twice', 'Arthur is emotional, and Hobson is encouraging.', 'The theme of humor', 'Darren calls for help, while Reed pulls the dog off him.', 'It slithers between her thighs', 'Yes, the breaking in foreshadows the lock picking', 'Calm', 'There are no explicit time constraints.', 'In a rocky plateau', 'It is a valley with spots of light', 'A dog', 'To communicate with his deceased uncle.', 'He turns on the night vision on the camera.', 'Colleagues', 'Arthur experiences a series of events that blur the line between reality and imagination.', 'Possibility of meeting his son', 'Creeping into a room', 'Working', 'Reed says "I got it," Darren moves behind Reed, Darren observes the broken sensor.', 'The characters distract the dog with food', 'Hobson', 'It is a bar of soap that stains hands; to prank', 'He becomes increasingly optimistic.', "Fairchild's hands are stained from a malfunctioning soap", '3', 'In an adjacent room', 'It represents his dwindling fortunes.', 'Pulls the dog off him', 'The acceptance of responsibility', 'Learning about his son', 'To reach a specific location', 'Stop drinking, or he will end up alone and miserable.', 'Motivating', 'From anxiety to excitement', 'In the car', 'It prompts Arthur to suggest leaving the room.', 'They exchange information', 'Surprised', 'They remain the same', 'From joking to nostalgic', 'Stay down, or they will be caught.', 'They use a thermal suit', 'She closes her eyes and focuses on staying calm without moving at all.', 'It jumps on him', "He doesn't have a reason to change", 'From caution to panic', 'The sound of a helicopter approaching', 'Surveys the living room'}
#
# === question_category 的唯一值（前100个样本）===
#   'Character and\nRelationship Dynamics'
#   'Narrative and\nPlot Analysis'
#   'Setting and\nTechnical Analysis'
#   'Temporal'
#   'Theme Exploration'
#
# === DeBERTa 手动预测测试 ===
# tokenizer_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/579 [00:00<?, ?B/s]
# spm.model:   0%|          | 0.00/2.46M [00:00<?, ?B/s]
# /usr/local/lib/python3.12/dist-packages/transformers/convert_slow_tokenizer.py:558: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/371M [00:00<?, ?B/s]
# Some weights of DebertaV2ForSequenceClassification were not initialized from the model checkpoint at microsoft/deberta-v3-base and are newly initialized: ['classifier.bias', 'classifier.weight', 'pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   Choice A: logit = -0.0255
#   Choice B: logit = -0.0253
#   Choice C: logit = -0.0259
#   Choice D: logit = -0.0254
#   Choice E: logit = -0.0254
#
#   Predicted: B
#   Label:     'From anxiety to excitement'
#   Match:     False

# %%
from datasets import load_dataset

dataset = load_dataset('tomg-group-umd/cinepile', split='test')

# 查看前20个 answer_key 的原始值
print("=== 前20个 answer_key ===")
for i in range(20):
    ak = dataset[i]['answer_key']
    print(f"  [{i}] type={type(ak).__name__}, value={repr(ak)}")

# 查看所有唯一值
print("\n=== 所有唯一 answer_key 值（完整测试集）===")
from collections import Counter
counter = Counter(str(dataset[i]['answer_key']) for i in range(len(dataset)))
for val, cnt in sorted(counter.items()):
    print(f"  {repr(val):10s} → {cnt} 条")
# Out:
# === 前20个 answer_key ===
#   [0] type=str, value='From anxiety to excitement'
#   [1] type=str, value='Suggests next steps'
#   [2] type=str, value='The rough foliage'
#   [3] type=str, value='She closes her eyes and focuses on staying calm without moving at all.'
#   [4] type=str, value='Rough and dense'
#   [5] type=str, value='They hear an aircraft approaching.'
#   [6] type=str, value='To reach a specific location'
#   [7] type=str, value='They become more confident'
#   [8] type=str, value='The sound of a helicopter approaching'
#   [9] type=str, value='Reed'
#   [10] type=str, value='The sound of a helicopter'
#   [11] type=str, value='In a rocky plateau'
#   [12] type=str, value='It is a valley with spots of light'
#   [13] type=str, value='They use a thermal suit'
#   [14] type=str, value='They are trying to remain undetected by the helicopter using thermal suits.'
#   [15] type=str, value='It illuminates the surrounding foliage.'
#   [16] type=str, value='Directly underneath'
#   [17] type=str, value='Colleagues'
#   [18] type=str, value='It slithers between her thighs'
#   [19] type=str, value='Reed says "I got it," Darren moves behind Reed, Darren observes the broken sensor.'
#
# === 所有唯一 answer_key 值（完整测试集）===
#   '"Delegation arrived this morning."' → 1 条
#   '"Dr. Watson, I have always been taken by your unwavering devotion to Mr. Holmes."' → 1 条
#   '"Goodbye."' → 1 条
#   '"Hi, friend"' → 1 条
#   '"How extraordinary."' → 1 条
#   '"I knew that."' → 1 条
#   '"I think we\'re gonna need more toilet paper."' → 1 条
#   '"Nothing. Nothing. I\'m fine."' → 1 条
#   '"You remind me of my old butler."' → 1 条
#   '0'        → 2 条
#   '1'        → 34 条
#   '1,000 square miles' → 1 条
#   '100%'     → 1 条
#   '15'       → 1 条
#   '2'        → 41 条
#   '3'        → 12 条
#   '4'        → 5 条
#   '5'        → 3 条
#   'A $1 bill featuring a duck in place of George Washington.' → 1 条
#   "A $1 bill with George Washington's portrait" → 1 条
#   'A Ouija board' → 1 条
#   'A Rolex watch' → 2 条
#   'A bad trip' → 2 条
#   'A baton'  → 1 条
#   'A bazooka made from a bicycle' → 2 条
#   'A beaver DJ.' → 1 条
#   'A bedroom' → 1 条
#   'A belt'   → 1 条
#   'A blonde girl with her mouth sewn shut' → 1 条
#   'A bomb exploding' → 1 条
#   'A bottle' → 1 条
#   'A box'    → 1 条
#   'A bright blur' → 2 条
#   'A bright blur moves across the room.' → 1 条
#   'A bright blur moves through the shot.' → 2 条
#   'A broken wire' → 1 条
#   'A broomstick' → 1 条
#   'A broomstick - to fly away' → 1 条
#   'A buckle' → 1 条
#   'A camera' → 1 条
#   'A cane'   → 3 条
#   'A cape.'  → 1 条
#   'A car and money' → 1 条
#   'A cat'    → 2 条
#   'A cell phone' → 1 条
#   'A cell phone.' → 1 条
#   'A chair'  → 2 条
#   'A chaotic and dangerous environment.' → 1 条
#   'A character from a TV show' → 1 条
#   'A childlike creature' → 1 条
#   'A cicada' → 3 条
#   'A cigarette' → 3 条
#   'A cigarette lighter' → 1 条
#   'A cinder block' → 2 条
#   'A city street' → 1 条
#   'A coat rack with a plastic garment bag' → 1 条
#   'A cold chill' → 1 条
#   'A comb'   → 1 条
#   'A compliment on her skin.' → 1 条
#   'A cool box' → 1 条
#   'A courtesy gesture' → 1 条
#   'A cricket bat' → 1 条
#   'A cup'    → 1 条
#   'A cup of tea' → 1 条
#   'A curling iron' → 1 条
#   'A cut'    → 1 条
#   'A dance stage' → 1 条
#   'A dark city skyline' → 1 条
#   'A decision to end the friendship.' → 1 条
#   'A demon'  → 1 条
#   'A desert road.' → 1 条
#   'A difference in values' → 1 条
#   'A dining room' → 1 条
#   'A discussion about becoming co-detectives.' → 1 条
#   'A dog'    → 1 条
#   'A dog running towards him' → 1 条
#   'A dollar bill' → 1 条
#   'A donkey' → 1 条
#   'A dreamcatcher' → 1 条
#   'A drink'  → 4 条
#   'A duck'   → 1 条
#   'A fear of abandonment' → 1 条
#   'A fight at the club' → 1 条
#   'A flame punch' → 1 条
#   'A flaming baton to entertain the visitors.' → 1 条
#   'A flaming baton.' → 1 条
#   'A flash of Evelyn from a video' → 1 条
#   'A flash of Evelyn from the video' → 1 条
#   'A flashback' → 1 条
#   'A flashlight' → 1 条
#   'A flyer.' → 1 条
#   'A food container' → 1 条
#   'A framed photograph on the wall' → 1 条
#   'A friend being attacked' → 1 条
#   'A fruit'  → 1 条
#   'A gas mask' → 1 条
#   'A gate'   → 1 条
#   'A ghost'  → 1 条
#   'A gift box' → 3 条
#   'A girl with her mouth sewn shut and hollow eyes' → 1 条
#   'A glass of sparkling wine.' → 1 条
#   'A glider' → 1 条
#   'A glimpse of a dark hallway is shown.' → 1 条
#   'A gloved hand switches off the ceiling light.' → 1 条
#   'A glue grenade launcher' → 1 条
#   'A gold ring' → 1 条
#   'A gold ring in the cake.' → 1 条
#   'A gold ring.' → 2 条
#   'A golf club' → 1 条
#   'A goofy dance' → 1 条
#   'A greeting' → 1 条
#   'A grin'   → 1 条
#   'A group of footfallers, a donkey, and men in white bathrobes' → 1 条
#   "A guard's exclamation" → 1 条
#   'A guitar' → 1 条
#   'A gun'    → 1 条
#   'A hall'   → 1 条
#   'A hamster' → 2 条
#   'A hanging stage prop' → 1 条
#   'A heated argument' → 1 条
#   'A heavy-duty metal door slides open.' → 1 条
#   'A human'  → 1 条
#   'A kettledrum' → 1 条
#   'A keychain' → 2 条
#   'A keychain with a picture of Seattle' → 1 条
#   'A knife'  → 1 条
#   'A lamp'   → 1 条
#   'A leak of classified information' → 1 条
#   'A leopard print cape' → 1 条
#   'A light'  → 1 条
#   'A lighter' → 3 条
#   "A lighty brick falls on Jack's wife." → 1 条
#   'A manila envelope' → 1 条
#   'A masked man' → 1 条
#   'A meeting place for the Infidel Motorcycle Club' → 1 条
#   'A mention of Abraham Lincoln Elementary' → 1 条
#   'A message' → 1 条
#   'A mirror' → 1 条
#   'A moon'   → 1 条
#   'A mouse'  → 1 条
#   'A mummified corpse' → 1 条
#   'A negotiator.' → 1 条
#   'A newspaper' → 1 条
#   'A painting.' → 1 条
#   'A pair of sunglasses' → 2 条
#   'A partnership in his business.' → 1 条
#   'A patient' → 1 条
#   'A patient in the house' → 1 条
#   'A penthouse' → 1 条
#   'A person' → 1 条
#   'A phone'  → 3 条
#   'A photograph of Howard with his parents' → 1 条
#   'A photograph of a blonde woman in a leopard coat' → 1 条
#   'A photograph of a known suspect' → 1 条
#   'A pie tin sticks to his face.' → 1 条
#   'A piece of fruit.' → 1 条
#   "A player's lack of focus" → 1 条
#   'A post from Adam' → 1 条
#   'A pouch'  → 1 条
#   'A private fantasy' → 1 条
#   'A promise to leave the bar.' → 1 条
#   'A purse.' → 1 条
#   'A raccoon.' → 1 条
#   'A rack of assorted animal hair whips' → 1 条
#   "A reference to things different yet similar in Howard's world" → 1 条
#   'A renewed sense of independence.' → 1 条
#   'A robbery' → 1 条
#   'A romantic partner' → 1 条
#   'A rope'   → 1 条
#   'A school uniform' → 1 条
#   'A screen is shown.' → 1 条
#   'A sculpture' → 1 条
#   'A service chute' → 1 条
#   'A set of blinds' → 1 条
#   'A shared meal.' → 1 条
#   "A shockwave emanates from the furnace, causing Sarah to be thrown back, while black smoke pours from Doris' mouth." → 1 条
#   'A small pouch.' → 1 条
#   'A smart police uniform' → 1 条
#   'A smoking curling iron protrudes from her mouth.' → 1 条
#   'A sound at an unsual time' → 1 条
#   'A space suit.' → 1 条
#   'A starlit sky' → 1 条
#   'A stick'  → 1 条
#   'A stole'  → 1 条
#   'A stranger' → 1 条
#   "A student's unique ballet performance." → 1 条
#   'A study with a bee habitat' → 1 条
#   'A stuffed bird' → 2 条
#   'A sultry look' → 1 条
#   'A suspicious bulge' → 1 条
#   'A taser.' → 1 条
#   'A tea laced with poison.' → 1 条
#   'A teacher intervenes to stop the fight.' → 1 条
#   'A teacup' → 1 条
#   'A trash bin' → 1 条
#   'A trash bin.' → 1 条
#   'A tree branch snaps.' → 1 条
#   'A turkey leg' → 1 条
#   'A vase of flowers' → 1 条
#   'A vehicle for stealing picnic baskets' → 1 条
#   'A vibrator' → 1 条
#   'A vodka bottle.' → 1 条
#   'A wallet' → 1 条
#   'A watch'  → 1 条
#   'A watch, to tell time' → 1 条
#   'A wedding ring' → 1 条
#   'A whip'   → 1 条
#   'A wire'   → 2 条
#   'A worm'   → 1 条
#   'A worm emerges from his nostril.' → 1 条
#   'Above them' → 1 条
#   'Accelerate away, or the shark will catch Maya.' → 1 条
#   'Accquitances' → 1 条
#   'Acquaintances' → 1 条
#   'Across the sand dunes' → 1 条
#   'Acting'   → 1 条
#   'Activate the paw scan, or the door will not open.' → 1 条
#   'Adam'     → 1 条
#   'Adam posts pictures, Val posts a message, Jess sends a Skype message.' → 1 条
#   'Adds a touch of humor' → 1 条
#   'Adds a touch of humour' → 1 条
#   'Administers an EpiPen' → 1 条
#   'Affectionate' → 1 条
#   'Afghan hounds' → 1 条
#   'Afternoon' → 1 条
#   'Against the stone slab' → 1 条
#   'Against the vanity' → 1 条
#   'Against the wall' → 1 条
#   'Age'      → 1 条
#   'Agent Butch' → 1 条
#   'Aggressively' → 1 条
#   'Agile and crab-like' → 1 条
#   'Agitated to panic' → 1 条
#   'Aim and fire the harpoon, or the shark will escape.' → 1 条
#   'Aim his gun, or Jack will kill Anna' → 1 条
#   'Aja wakes and Shaina listens.' → 1 条
#   'Aja wakes up, and Shaina listens.' → 1 条
#   'Alex is not there.' → 1 条
#   'Alex is scared, and her father is amused.' → 1 条
#   'Alex moves closer to Robbie, Robbie runs out, cut to black.' → 1 条
#   "Alex's father" → 1 条
#   "Alex's room" → 1 条
#   'Alex.'    → 2 条
#   'Alice'    → 1 条
#   'All A, B and C' → 1 条
#   'All of the above' → 10 条
#   'All of the above.' → 1 条
#   'Allows her to escape the shark' → 1 条
#   'Allows him to enter a secret room' → 1 条
#   'Allows them to practice aiming at moving targets' → 1 条
#   'Amanda becomes angry, and Chris is scared.' → 1 条
#   'Amanda recounts a painful past event, linking it to her current insistence.' → 1 条
#   'Amanda slaps her mother.' → 1 条
#   'Amanda\'s mother calls her a "sweetie."' → 1 条
#   "Amanda's story about her mother" → 1 条
#   'Amused'   → 2 条
#   'Amusement' → 1 条
#   'An American flag waves in front of rows of white gravestones.' → 1 条
#   'An EpiPen' → 2 条
#   'An EpiPen for allergic reaction.' → 1 条
#   'An amalgamation of serene acceptance and inevitable closure' → 1 条
#   'An application' → 1 条
#   'An empty space' → 1 条
#   'An engraved stone' → 1 条
#   'An explanation' → 1 条
#   'An injured person' → 1 条
#   'An operations room' → 1 条
#   'An operations room.' → 1 条
#   'An ultrasound monitor' → 1 条
#   'An unidentified character' → 1 条
#   'Anastasia' → 1 条
#   'Anastasia asserts dominance over Gia.' → 1 条
#   'Anastasia confronts Gia about her behavior.' → 1 条
#   'Anger'    → 9 条
#   'Anger and betrayal, feeling that the pregnancy is a personal affront.' → 1 条
#   'Angry'    → 19 条
#   'Angry and aggressive' → 1 条
#   'Animal motif graffiti' → 1 条
#   'Animal motif graffiti on the walls' → 1 条
#   'Animated equations' → 1 条
#   'Anna'     → 2 条
#   'Anna drops her purse and coat, tries a light switch, and turns on a lamp.' → 1 条
#   'Anna enters the office, apologizes, and sits down.' → 1 条
#   'Anna is confrontational, while Christian is ignorant.' → 1 条
#   'Anna is excited, while Christian is hesitant.' → 1 条
#   'Anna is serious, and Jack is amused.' → 1 条
#   'Anna is shocked, and Lila is submissive.' → 1 条
#   'Anna is standing in front of Christian.' → 1 条
#   'Anna is standing, Jack is standing' → 1 条
#   'Anna is terrified, while Mia is defiant' → 1 条
#   'Anna looks out the back window, the SUV crosses railroad tracks, Anna glances out the windshield' → 1 条
#   'Anna shoots Jack in the leg.' → 1 条
#   "Anna visits the doctor, learns she's pregnant, and tells Christian." → 1 条
#   "Anna's pregnancy news" → 1 条
#   'Anna\'s request for a "vanilla relationship"' → 1 条
#   'Annoyed'  → 3 条
#   "Answer Sarah's question, or she will be ignored." → 1 条
#   'Answers immediately' → 1 条
#   'Anxious'  → 4 条
#   'Anxious and concerned' → 1 条
#   'Anxious and distracted' → 1 条
#   'Anxious and hesitant' → 1 条
#   'Anxious loyalty' → 1 条
#   'Anxious to calm' → 1 条
#   'Anxious to excited' → 2 条
#   'Anxious.' → 1 条
#   'Apologetic' → 4 条
#   'Apologize to Charlie, or he will never forgive her' → 1 条
#   'Apologizes' → 1 条
#   'Apologizing' → 1 条
#   'Applauding' → 1 条
#   'Applying lipstick on Layla' → 1 条
#   'Approaches her' → 1 条
#   "Argues that it's too blurry to make out any details." → 1 条
#   'Arlington National Cemetery' → 2 条
#   'Arrow'    → 1 条
#   'Arthur experiences a series of events that blur the line between reality and imagination.' → 1 条
#   'Arthur is emotional, and Hobson is encouraging.' → 1 条
#   "Arthur scrambles out of bed. Arthur looks at a wide-eyed man in brown. Hobson sits on Arthur's bed. Hobson fixes Arthur with his steely gaze. Arthur's eyes bulge." → 1 条
#   'Arthur tries to establish camaraderie with Fairchild as a way to cope with missing Hobson.' → 1 条
#   'As a stone-cold fox.' → 1 条
#   'As a symbol of his power' → 1 条
#   'As a weapon' → 1 条
#   'As contestants' → 1 条
#   'As employer-employee' → 1 条
#   'As ex-lovers' → 1 条
#   'As neighborhood friends' → 1 条
#   'As strangers at the aquarium' → 1 条
#   'Asks about Mrs. Bark' → 1 条
#   'Assertive' → 1 条
#   'Asteroid hurtles towards Earth, Sherman plants explosive, Sherman detonates explosive, Asteroid explodes' → 1 条
#   "At Burke's place" → 1 条
#   'At Lucinda the cat' → 1 条
#   "At Sam's group" → 1 条
#   'At a cemetery, making the conversation somber.' → 1 条
#   'At home'  → 3 条
#   'At the French doors' → 1 条
#   'At the Hammerhead Club' → 1 条
#   'At the airport' → 1 条
#   'At the camp' → 1 条
#   'At the dining table' → 1 条
#   'At the fireplace' → 1 条
#   'At the gate' → 1 条
#   'At the ground floor' → 1 条
#   'At the man-whore union' → 1 条
#   "At the shark's dorsal fin" → 1 条
#   'At the theater door' → 1 条
#   'At the theater door.' → 1 条
#   'Attaches a rope to his trousers' → 1 条
#   'Attempts to identify the source of the shaking' → 1 条
#   'Aunt Bailey' → 2 条
#   'Authoritative' → 1 条
#   'Ava admires the fish painting, then they enter the aquarium.' → 1 条
#   'Away from Charlie' → 1 条
#   'Away from Gia' → 1 条
#   'Awkward.' → 1 条
#   'Back into the tank' → 1 条
#   'Back window' → 1 条
#   'Backs away' → 1 条
#   'Baffled'  → 1 条
#   'Bandage his head, or it will get infected.' → 1 条
#   'Barb'     → 2 条
#   "Barb finds Sharif's body, opens the door, and finds the girl." → 1 条
#   "Barb is calm, the girl doesn't interact with the body." → 1 条
#   'Barb is indifferent, Willis is concerned.' → 1 条
#   'Barb must descend on a wire from the window, or she and the girl will be caught.' → 1 条
#   "Barb taking keys from Sharif's body" → 1 条
#   'Base'     → 1 条
#   'Battered and upside down' → 1 条
#   'Beaver'   → 1 条
#   'Because she unleashed hell on the world' → 1 条
#   'Becomes grateful' → 1 条
#   'Becomes hairless' → 1 条
#   'Becomes more apologetic' → 1 条
#   'Becomes more confrontational' → 1 条
#   'Becomes more distant' → 1 条
#   'Becomes more excited' → 1 条
#   'Becomes more sympathetic' → 1 条
#   'Behind'   → 1 条
#   'Behind Maya' → 2 条
#   'Behind the board.' → 1 条
#   'Behind the warehouse' → 1 条
#   'Being lost in her thoughts' → 1 条
#   'Being thrown to the back of the shuttle' → 1 条
#   'Being violent' → 1 条
#   'Bella accepts it, and Jacob leaves.' → 1 条
#   'Bella argues with him' → 1 条
#   'Bella confesses her love to Jake.' → 1 条
#   'Bella cutting her finger' → 2 条
#   'Bella drops her gaze.' → 1 条
#   'Bella enters, slaps the young man, Paul transforms into a wolf.' → 1 条
#   'Bella falls, Jacob helps, Jacob worries.' → 1 条
#   'Bella is calm, Jacob is worried.' → 1 条
#   'Bella is calm, and Edward is concerned.' → 1 条
#   'Bella is determined, and Edward is reluctant.' → 1 条
#   'Bella is sad, Edward is angry' → 1 条
#   'Bella is sad, Edward is conflicted.' → 1 条
#   'Bella is sitting on her bed.' → 1 条
#   'Bella pleads with Felix to kill her, while Arrow motions for Felix to wait.' → 1 条
#   'Bella remembers the story, and Jacob is relieved.' → 1 条
#   'Bella slaps him, and Paul holds him back.' → 1 条
#   'Bella slaps the young man.' → 1 条
#   'Bella smiles, then slices her finger on the wrapping.' → 1 条
#   'Bella tries to stop Jacob from leaving.' → 1 条
#   "Bella's decision to ride the bike again" → 1 条
#   "Bella's injury" → 1 条
#   "Bella's insistence on becoming like Edward" → 1 条
#   "Bella's slap" → 1 条
#   'Ben argues with his father' → 1 条
#   'Ben calls out "Alex."' → 1 条
#   'Ben climbs faster, Kim covers her face.' → 1 条
#   'Ben walks towards the stairs, looks in Alex\'s room, and calls out "Alex."' → 1 条
#   'Bender knocks over his table, rushes to the girls, and hisses at them.' → 1 条
#   'Benter'   → 1 条
#   'Beside him' → 1 条
#   'Beside it' → 1 条
#   'Beverly'  → 1 条
#   'Beverly runs her fingers through his plumage, drapes a blanket over him, and finds his wallet.' → 1 条
#   'Beverly starts to feel more comfortable and open.' → 1 条
#   'Bill'     → 2 条
#   'Bill and Everett' → 1 条
#   'Billy hits Charlie' → 1 条
#   'Billy.'   → 1 条
#   'Birds look better when stuffed due to their passive nature.' → 1 条
#   'Bites him' → 1 条
#   'Bites his groin' → 1 条
#   'Black'    → 11 条
#   'Black and white' → 1 条
#   'Black confronts Manuel and Black shoots Manuel.' → 1 条
#   'Black confronts Manuel, Black shoots Manuel, Manuel stabs Black.' → 1 条
#   'Black is calm and Manuel is scared.' → 1 条
#   'Black liquid' → 1 条
#   'Black telling Mr. Emil about loose end' → 1 条
#   'Blaine Polda' → 1 条
#   'Blaine communicates with the entity.' → 1 条
#   'Blaine puts on the gas mask, kicks the table, and acts to communicates with the entity.' → 1 条
#   'Blair'    → 1 条
#   'Blair calls the police, Blair types the address, Blair sends the address.' → 1 条
#   'Blair is relieved, Jess is scared.' → 1 条
#   'Blair requests her help' → 1 条
#   'Blocks his path' → 1 条
#   'Blonde'   → 3 条
#   'Bloody'   → 1 条
#   'Blows a dart into it' → 1 条
#   'Blows it out' → 1 条
#   'Blue'     → 8 条
#   'Blue crystals' → 1 条
#   'Bob their heads' → 1 条
#   'Bobby J cheats, Ben climbs the tree, a branch snaps, Ben punches the button, and Lance flings the grease can.' → 1 条
#   'Body shape' → 1 条
#   "Bomb discovery, Queen's safety, bomb defusal" → 1 条
#   'Boo-Boo'  → 1 条
#   "Boo-Boo's motivational speech" → 3 条
#   'Both Charlie and Phil reject.' → 1 条
#   'Both Gus and Old Deuteronomy are amused.' → 1 条
#   'Both Kitty Eagle-O and little scrumptious are excited.' → 1 条
#   'Both Mr. Ranger and Yogi are sad.' → 1 条
#   'Both Taylor and Christian' → 1 条
#   'Bottle'   → 1 条
#   'Bounces on a rubber ring' → 1 条
#   'Bouncing on a rubber ring' → 1 条
#   'Bow to Brian, or he will punish her.' → 1 条
#   'Bows'     → 1 条
#   'Brandon explains he was burying his condor.' → 1 条
#   'Brandon ruins the condor, May enters with a cake, May finds dirt on the sweater.' → 1 条
#   'Break off the kiss, or he will lose control.' → 1 条
#   'Brenda'   → 1 条
#   'Brian'    → 1 条
#   'Brian interacts with Riley about her defiance.' → 1 条
#   'Brian winks at Riley' → 1 条
#   'Brian winks, Riley dances, Chris steps forward' → 1 条
#   'Brightens' → 1 条
#   "Brings her hands to her face, gazes out at the city, crosses the room, lies down in bed, sits up quickly, glances at Christian's empty side of the bed, makes a phone call, sits on the couch by the fireplace, and lies down on the couch" → 1 条
#   'Broken'   → 1 条
#   'Brothers' → 1 条
#   'Brown'    → 1 条
#   'Bruised'  → 1 条
#   'Brunette' → 1 条
#   'Brushing eye shadow' → 1 条
#   'Buck is defensive, and Charlie is accusatory.' → 1 条
#   'Buck is more defensive than Charlie.' → 1 条
#   'Buck is retiring' → 1 条
#   'Buck is sitting on a bench, Charlie is standing in front of him.' → 1 条
#   'Buck takes a deep breath.' → 1 条
#   'Buck, who hangs his arm over the back of the bench and looks away.' → 1 条
#   'Burke'    → 1 条
#   'Burke feels his way along the piano, Julia crawls under it, Burke blocks her path.' → 1 条
#   'Burke is standing in front of Julia.' → 1 条
#   'Burke is surprised, Julia is scared.' → 1 条
#   'Burke turns and faces the window.' → 1 条
#   "Burke's grin fades." → 1 条
#   'Burly men' → 1 条
#   'Burning'  → 2 条
#   'Bury his condor, or it will decompose.' → 1 条
#   'Butch puts his paw on the door.' → 1 条
#   'Buttons a cloak' → 1 条
#   'By agreeing with Anna' → 1 条
#   'By appealing to her emotions' → 1 条
#   'By asking questions' → 1 条
#   'By attacking him' → 1 条
#   'By clearly demanding Gia stop speaking to Christian as if she were not present and asserting her own authority.' → 1 条
#   'By demonstrating that the accused is a doppelganger and not Moriarty.' → 1 条
#   'By explaining that the shaking is caused by a truck passing by' → 1 条
#   'By explicitly telling Gia to stop making eyes at Christian and to refer to her as "Mrs. Gray."' → 1 条
#   'By highlighting her authority through subtle cues' → 1 条
#   'By inviting him to sit down' → 1 条
#   'By making a joke about CNN' → 1 条
#   'By offering a token of peace in exchange for their flag' → 1 条
#   'By saying "you need help"' → 1 条
#   'By sending messages' → 1 条
#   'By standing close to him' → 1 条
#   'By ultralight aircraft' → 1 条
#   'By unleashing a devastating sound' → 1 条
#   'By using a stage prop as a weapon' → 1 条
#   'By using a wire to descend from a window' → 1 条
#   "Caesar's intelligence surpasses the average human's, but he still fails the creativity test." → 1 条
#   'Caked with dirt and leaves' → 1 条
#   'Call Anna tomorrow, or she will be angry.' → 1 条
#   'Call for help' → 1 条
#   'Call the hotel, or he will miss his dinner.' → 1 条
#   "Call the police, or Heinz's body will be discovered." → 1 条
#   'Call the police, or Jess will be killed.' → 1 条
#   'Calls his name' → 1 条
#   'Calm'     → 6 条
#   'Calm Lee down, or she will panic.' → 1 条
#   'Calm and analytical' → 1 条
#   'Calm and collected' → 1 条
#   'Calm to angry' → 1 条
#   'Calmness and reassurance' → 1 条
#   'Cameraman' → 1 条
#   'Camille'  → 1 条
#   'Camille bites the man, the man is dragged out.' → 1 条
#   "Camille runs up and bites the man's groin, the man is dragged out, the barman pours a drink for Willis." → 1 条
#   'Camp Driftwood' → 1 条
#   'Candles'  → 1 条
#   'Candles light spontaneously, Sarah sits against the stone slab, a decayed female form appears.' → 1 条
#   'Canes'    → 1 条
#   'Carlos'   → 1 条
#   'Carlos Santana' → 1 条
#   'Carlos and Luis' → 1 条
#   "Carlos ordering Luis's execution" → 1 条
#   'Carlos runs to the gate and stops, Everett and Larry hop in, Kilgore mans the gun, and Bill drives away.' → 1 条
#   'Carlos shoots the puppet, Ken faints, Luis arrives, the American army shows up.' → 1 条
#   "Carlos shoots the puppet, Ken faints, Luis fails to get the tribute, Carlos orders Luis's execution" → 1 条
#   'Carlos shouts, "Damn you, Everett!"' → 1 条
#   'Casual'   → 1 条
#   'Casually' → 1 条
#   "Cat leaps onto truck, young cat flips, gray tabby beckons young cat, black and white cat's hat falls off" → 1 条
#   'Catch the queen bee using a helmet' → 1 条
#   'Catherine is uncomfortable and asks Diggs to stop, Diggs is persistent.' → 1 条
#   'Catherine retrieves the collar and uses it to pick the lock.' → 1 条
#   "Cats appear and rub against Patience's legs." → 1 条
#   'Cautiously' → 1 条
#   'Chaotic'  → 1 条
#   'Characters talk about Harry Turner, plane takes off, plane lands' → 1 条
#   'Charlie is disgusted, and Jack laughs.' → 1 条
#   'Charlie looks confused upstairs.' → 1 条
#   'Charlie reminisces about the past with a sense of wistfulness, whereas Buck accepts his current reality without yearning for the past.' → 1 条
#   "Charlie's compliment" → 2 条
#   "Charlie's initiative to start a daycare center after losing his job" → 1 条
#   "Charlie's office window is broken." → 1 条
#   'Chasing them' → 1 条
#   'Checks her arm' → 1 条
#   'Checks her phone' → 1 条
#   'Checks her phone and reads a message' → 1 条
#   'Chili peppers' → 1 条
#   'Chokes him' → 2 条
#   'Chopped down' → 1 条
#   'Chris'    → 1 条
#   'Chris hands Amanda the application, she removes her hat, and she finds it covered in characters.' → 1 条
#   'Chris is angry, and Riley is scared.' → 1 条
#   'Chris is driving, Harry is in the passenger seat.' → 1 条
#   'Chris reads a message.' → 1 条
#   "Chris smiles, Harry's head hits the headrest, Chris jerks the wheel." → 1 条
#   'Chris tugs the wheel, and Harry screams.' → 1 条
#   "Chris's hand trembles as she holds the knife covered in black liquid." → 1 条
#   "Chris's hand trembles as she holds the knife, and she steps past Marty's motionless body." → 1 条
#   "Chris's refusal to pay respects" → 2 条
#   'Christian' → 2 条
#   'Christian as a dominant.' → 1 条
#   "Christian cradles Anna's neck in his hand and presses her against the door." → 1 条
#   'Christian follows Anna to her building.' → 1 条
#   'Christian grabs his coat, Anna sits down, Christian opens the gift.' → 1 条
#   'Christian introduces Gia to Anastasia.' → 1 条
#   'Christian is not present in the scene' → 1 条
#   'Christian is playful, and the woman is confused.' → 1 条
#   'Christian is standing, Anna is sitting' → 1 条
#   'Christian offers her toast.' → 1 条
#   "Christian pours drinks, Christian reveals his mother's death, Anna apologizes." → 1 条
#   'Christian reaches into his pocket and pulls out the gift box.' → 1 条
#   'Christian takes off his shirt.' → 1 条
#   "Christian's dominant lifestyle." → 1 条
#   "Christian's explanation of the room's purpose." → 1 条
#   "Christian's phone call." → 1 条
#   "Christian's reaction to the news" → 1 条
#   'Christian.' → 1 条
#   'Christy is confused and asks what is happening.' → 1 条
#   'Christy must stay with Ryan, or he cannot be there.' → 1 条
#   'Christy squeezes her eyes shut tightly. Ryan carries Lila out. Christy watches Ryan carry Lila out. Ryan says, "So this is the tape I was telling you about from last night."' → 1 条
#   'Claire'   → 2 条
#   "Claire and Noah's relationship becomes violent." → 1 条
#   "Claire arrives at Vicky's house, Vicky's body falls on Claire, Claire calls 9-1-1." → 1 条
#   "Claire dabs Noah's hand, Noah and Claire argue, Claire leaves" → 1 条
#   'Claire enters the bathroom, finds the overflowing sink, and pulls paper towels from the drain.' → 1 条
#   'Claire finds the overflowing sink, pulls paper towels from the drain, and notices the wall message.' → 1 条
#   'Claire is amused, while Vicki is concerned.' → 1 条
#   'Claire is scared and tries to leave, while Noah is angry and aggressive.' → 1 条
#   'Claire is scared, while Noah is protective.' → 1 条
#   "Claire's accusation of murder." → 1 条
#   'Clare runs to Josh' → 1 条
#   'Clean'    → 1 条
#   'Climbing' → 1 条
#   'Climbs'   → 1 条
#   'Clings to the ring' → 1 条
#   'Close'    → 1 条
#   'Close to the latticework amidst a cluttered pile.' → 1 条
#   'Close together' → 1 条
#   'Closed'   → 2 条
#   'Closed and sealed' → 1 条
#   'Closes the cage door' → 1 条
#   'Closes the door' → 1 条
#   'Cloudy and dull' → 1 条
#   'Clutches it in his teeth' → 1 条
#   'Co insults Mike.' → 1 条
#   'Cocks an eyebrow' → 1 条
#   'Cocks her head' → 1 条
#   'Coiling'  → 1 条
#   'Collaborating' → 1 条
#   'Collapsed' → 1 条
#   'Colleagues' → 7 条
#   'Comb'     → 1 条
#   'Comforts her' → 1 条
#   'Complimentary' → 1 条
#   'Composed' → 1 条
#   'Concerned' → 5 条
#   'Concerned.' → 1 条
#   'Condescending' → 1 条
#   'Confident' → 1 条
#   'Confident and assertive' → 1 条
#   'Confront Gia about her behavior, or Gia will continue to disrespect her.' → 1 条
#   'Confrontational' → 2 条
#   'Confronts the Komodo dragon' → 1 条
#   'Confused' → 4 条
#   'Confused and uncertain' → 1 条
#   'Confused to Angry' → 1 条
#   'Confusion' → 3 条
#   'Conscious' → 1 条
#   'Content'  → 2 条
#   'Continues blocking pucks' → 1 条
#   'Continues walking' → 1 条
#   'Contrite' → 1 条
#   'Convenience store' → 1 条
#   'Cops appear, aircraft takes off, Howard forces officers to duck' → 1 条
#   'Cossack'  → 1 条
#   'Covered in black liquid' → 1 条
#   'Covers her face.' → 1 条
#   'Cradles it' → 1 条
#   'Crawling' → 1 条
#   'Crawling with cicadas' → 1 条
#   'Crawls on the bed' → 1 条
#   'Crawls to it' → 1 条
#   'Crazed'   → 1 条
#   'Creates a competitive atmosphere' → 1 条
#   'Creates a sense of anticipation' → 3 条
#   'Creates a sense of intimacy' → 1 条
#   'Creates a sense of mystery' → 1 条
#   'Creates a tense enviornment' → 1 条
#   'Creates tension' → 1 条
#   'Creeping into a room' → 1 条
#   'Cricket bat' → 1 条
#   'Crosses him out of the window' → 1 条
#   'Crouching' → 1 条
#   'Curiosity' → 2 条
#   'Curious'  → 1 条
#   'Curious to unease' → 1 条
#   'Cut Victoria' → 1 条
#   'Cutting a ribbon' → 1 条
#   "D'Andre"  → 1 条
#   "D'Andre notices a creature, Jamarcus arrives, they shoot at the creature." → 1 条
#   'Dale'     → 1 条
#   'Dale grimaces and holds his breath' → 1 条
#   'Dan'      → 1 条
#   'Dan and his boss' → 1 条
#   'Dan and his boss discuss the future of their lab.' → 1 条
#   'Dan falls after slipping on a glass bottle.' → 1 条
#   "Dan is amused, while Dan's boss is concerned." → 1 条
#   'Dan is knocked unconscious and Jody tries to wake him up.' → 1 条
#   'Dan is scared, Tammy is calm.' → 1 条
#   "Dan's boss expresses concern about Caesar's progress." → 1 条
#   "Dan's childhood neighbor Max throwing plates." → 1 条
#   'Dance better than Kendra, or she will be overshadowed.' → 1 条
#   'Dances'   → 1 条
#   'Dancing in front of her' → 1 条
#   'Dancing on stage' → 1 条
#   'Dangling a skunk.' → 1 条
#   'Dark'     → 2 条
#   'Dark and gloomy' → 1 条
#   'Dark and ominous' → 1 条
#   'Dark shapes and particles rising towards the second floor' → 1 条
#   'Darren calls for help, while Reed pulls the dog off him.' → 1 条
#   'Daryl'    → 1 条
#   'Day'      → 1 条
#   'Dazed'    → 1 条
#   'Debbie'   → 1 条
#   'Debbie cleans the attic, then finds something.' → 1 条
#   'Debbie cleans the attic.' → 1 条
#   'Debbie is enthusiastic, and Sarah is wary.' → 1 条
#   'Defeated' → 1 条
#   'Defends herself' → 1 条
#   'Defensive' → 2 条
#   'Defiance' → 1 条
#   'Deflects the blame' → 1 条
#   'Delta symbol' → 1 条
#   'Demonic'  → 1 条
#   'Demonstrates an attempt to regain composure' → 1 条
#   'Demonstrating a gesture of trust' → 1 条
#   'Denial'   → 1 条
#   'Depicts it as a bustling center of operations' → 1 条
#   'Descending on a wire from a window' → 1 条
#   'Desperation' → 1 条
#   'Destroying the evidence' → 1 条
#   'Determination' → 2 条
#   'Determined' → 1 条
#   'Deuce'    → 4 条
#   'Deuce and Doocy argue about calling the police.' → 1 条
#   'Deuce and TJ sneak in, Enzo goes to the tanning room, Deuce and TJ enter the grand room.' → 1 条
#   'Deuce dives into the aquarium tank to remove the cigarette, potentially endangering himself.' → 1 条
#   'Deuce dives into the tank to retrieve something' → 1 条
#   'Deuce finds Heinz passed out, Doocy puts in a good word, Heinz is discovered dead.' → 1 条
#   'Deuce is confused, and Ava is annoyed.' → 1 条
#   'Deuce is shocked, while TJ is pragmatic.' → 1 条
#   'Deuce physically hurls a midget porn star out of the window, leading to a commotion outside.' → 1 条
#   'Deuce removes the man from the situation' → 1 条
#   'Deuce sees the line of studs, then Eva enters the house.' → 1 条
#   "Deuce's intervention shows his care for the aquarium" → 1 条
#   "Deuce's love for fish and his knowledge of fish species" → 1 条
#   "Deuce's realization of the midget porn star's actions" → 1 条
#   'Develops a limp' → 1 条
#   "Diggs clenches his jaw, lets go, Shane takes the jacket off, puts it on the floor, and takes Diggs' paw." → 1 条
#   'Diggs confesses his feelings, Catherine picks the lock, they escape.' → 1 条
#   'Diggs is beside Catherine' → 1 条
#   'Diggs lets go, and Shane takes it off.' → 1 条
#   'Diggs will be more comfortable' → 1 条
#   "Diggs' collar buckle" → 1 条
#   'Dim and somber' → 1 条
#   'Dim lighting creates a mysterious atmosphere.' → 1 条
#   'Directly underneath' → 1 条
#   'Disable the queen, or the bees will turn on them.' → 1 条
#   'Disabling the queen' → 1 条
#   'Disappointed' → 2 条
#   'Disappointment' → 1 条
#   'Disapproving' → 1 条
#   'Disarm the wrestler.' → 1 条
#   'Discussing a personal arrangement' → 1 条
#   'Disgust'  → 2 条
#   'Disgusted' → 2 条
#   'Dislodge the car keys' → 1 条
#   'Dislodges from the neck' → 1 条
#   'Dismissive' → 1 条
#   'Displays immediate dread' → 1 条
#   'Disrespect' → 1 条
#   'Distant'  → 1 条
#   'Distracted' → 1 条
#   'Distraught and passionate' → 1 条
#   'Dive back in' → 1 条
#   'Diving into the tank to retrieve the cigarette' → 1 条
#   'Doctor and patient' → 4 条
#   'Does a dance' → 1 条
#   "Doesn't change" → 1 条
#   "Doesn't reveal anything about her intentions" → 1 条
#   'Dog HQ'   → 1 条
#   'Dogs of all shapes and sizes go about their business as the main characters observe.' → 1 条
#   'Dogs of various breeds go about their tasks.' → 1 条
#   'Donkey'   → 1 条
#   "Doris grabs Lane's wrist and struggles with the planchette." → 1 条
#   "Doris' mouth hangs open and black smoke billows from it." → 1 条
#   'Downstairs' → 2 条
#   'Dr. Watson' → 1 条
#   'Dr. Watson feels nostalgic after thinking about solving crimes with Sherlock Holmes.' → 1 条
#   'Dr. Watson interacts with Sherlock Holmes about becoming co-detectives.' → 1 条
#   'Dr. Watson is against the idea of becoming a co-detective.' → 1 条
#   'Drake'    → 2 条
#   'Dressed in camouflage uniforms' → 1 条
#   'Drink'    → 1 条
#   'Drinking a lot of water.' → 1 条
#   'Drinking coffee' → 1 条
#   'Drinking tea' → 1 条
#   'Drops her gaze' → 2 条
#   'Drops her purse, takes off her shoes, turns on a lamp' → 1 条
#   'Drops it into the tank' → 1 条
#   'Ducks'    → 1 条
#   'Dump the ejaculate into the blender, or it will spoil' → 1 条
#   'Durfee ducks his head, Bob follows, Benter steals himself, Shelly struggles to maintain composure' → 1 条
#   'Dusty and antique' → 1 条
#   'Each other' → 1 条
#   'Edgar'    → 1 条
#   "Edgar asks about Charlie's condition." → 1 条
#   'Edgar creeps out of the house.' → 1 条
#   'Edgar flinches and remains silent.' → 1 条
#   'Edgar is indifferent' → 1 条
#   "Edgar's brutal and violent murder of his former wife." → 1 条
#   'Edward apologizes, Charlie enters, Charlie leaves' → 1 条
#   "Edward is holding Bella's hand." → 1 条
#   "Edward opens Bella's door, Bella asks for a kiss, Edward kisses Bella." → 1 条
#   'Edward shoves Jake.' → 1 条
#   "Edward's anxiety about the potential consequences of Bella becoming a vampire" → 1 条
#   "Edward's super speed allows him to dodge Felix's attacks" → 1 条
#   'Edward, by climbing through the window.' → 1 条
#   'Ellen panics, Jake remains calm' → 1 条
#   'Ellen senses danger' → 1 条
#   'Embarrassment' → 1 条
#   'Emerges'  → 1 条
#   'Emily'    → 1 条
#   'Emily and Lee hear a noise from the recorder.' → 1 条
#   "Emily discovers symbols on Lila's wall, then in the girls' rooms." → 1 条
#   'Emily warns Lee about something' → 1 条
#   'Emotional appeals' → 1 条
#   'Employs a series of tricks and tools.' → 1 条
#   'Enemies'  → 5 条
#   'Energetic' → 1 条
#   'Enhances her sensuality' → 1 条
#   'Entering through the window' → 1 条
#   'Enters a seperate room' → 1 条
#   'Enthusiastic' → 1 条
#   'Entranced' → 1 条
#   'Erica is determined, while her mother is skeptical.' → 1 条
#   'Escalation of conflict' → 1 条
#   "Escape Felix's grip, or he will be killed." → 1 条
#   'Escape the house, or Noah will kill her.' → 1 条
#   'Eva'      → 1 条
#   'Everett is lying on top of the wrestler.' → 1 条
#   'Everett pins the wrestler, Carlos applauds, and Everett pulls off his mask.' → 1 条
#   "Everett's group escapes in a Humvee." → 1 条
#   'Everyone in the bar.' → 1 条
#   'Excited'  → 11 条
#   'Exhibits a flinch' → 1 条
#   'Expected Boo Boo, saw a glider' → 1 条
#   "Expected the woman's car, found nothing" → 1 条
#   'Expected to see the childlike creature, but the little girls appeared' → 1 条
#   'Expresses doubt' → 1 条
#   'Eyes'     → 1 条
#   'Eyes the empty bed' → 1 条
#   'Facilitates their reunion' → 1 条
#   'Facing Lila' → 1 条
#   'Facing each other' → 2 条
#   'Facing him' → 3 条
#   'Fairchild' → 2 条
#   'Fairchild greets Mr. Mark' → 1 条
#   'Fairchild is confused, and Arthur is amused.' → 1 条
#   "Fairchild's hands are stained from a malfunctioning soap" → 1 条
#   "Fairchild's hands get stained, he reports it, and Arthur jokes about it." → 1 条
#   'Falls off' → 1 条
#   'Family'   → 1 条
#   'Far away from it' → 1 条
#   'Fascinated' → 1 条
#   'Father and daughter' → 2 条
#   'Father and son' → 2 条
#   'Fear'     → 13 条
#   'Fear of the unknown' → 1 条
#   'Fearful'  → 3 条
#   'Fearful to confident' → 1 条
#   'Felipe introduces her family, Jill performs a dance, and the granny is revived with jalape������os.' → 1 条
#   'Felix forces Edward to his knees and twists his head up toward Arrow.' → 1 条
#   'Felix punches through it to grab Edward' → 1 条
#   'Felix punches through the marble bench.' → 1 条
#   'Felix turns Edward around.' → 1 条
#   'Felix uses them to slam Edward down' → 1 条
#   'Fidgets'  → 1 条
#   'Fight for Jellystone, or it will be lost.' → 1 条
#   'Fighting' → 1 条
#   'Fighting for Jellystone' → 1 条
#   'Fights back' → 1 条
#   'Figure out the problem, or he will be alone.' → 1 条
#   'Filled with inky strings and particles rising' → 1 条
#   'Filled with players and pucks landing in the net' → 1 条
#   "Find Jason's transcripts, or he will be killed." → 1 条
#   'Find Jen, or she will be killed.' → 1 条
#   'Find a light for Manuel, before Manuel dies.' → 1 条
#   'Find a spit cup, or he will get sick' → 1 条
#   'Find beer, or Johnny will get angry.' → 1 条
#   "Find her keys, or she won't be able to get into her car." → 1 条
#   'Find information about Drake Chibu, or everyone will be killed.' → 1 条
#   'Find out what the girl said, or she will bite him again.' → 1 条
#   'Find out who Billie is, or she will continue to be accused.' → 1 条
#   'Find the EpiPen, or Kevin will die.' → 1 条
#   'Find the patient, or he will escape.' → 1 条
#   'Finding the killer' → 1 条
#   'Finds a map' → 1 条
#   'Finds it unusual' → 1 条
#   'Fingerprints' → 1 条
#   'Fingerprints that match the man on trial.' → 1 条
#   'Fireplace' → 1 条
#   'Firing his revolver' → 1 条
#   'Fitzroy'  → 1 条
#   "Fitzroy drops his camera, Fitzroy swims towards Kathy, Kathy breaks the water's surface." → 1 条
#   "Fitzroy drops his camera, Kathy breaks the water's surface, Brody fiddles with the harpoon." → 1 条
#   "Fix Heather's car, or she will be stranded." → 1 条
#   'Flame'    → 1 条
#   'Flaps at the flames' → 2 条
#   'Flinches' → 1 条
#   'Flips her over' → 2 条
#   'Flirtatious' → 1 条
#   'Flirty'   → 1 条
#   'Floating in the water' → 1 条
#   'Flying a commercial plane' → 1 条
#   'Flying broomstick' → 1 条
#   'Fogged with condensation' → 1 条
#   'Follow his rules' → 1 条
#   'Food'     → 1 条
#   'Forced'   → 1 条
#   'Forcefully remove her' → 1 条
#   'Forces a smile' → 1 条
#   'Forcing her daughter to hold a broken lamp wire to share in her physical pain.' → 1 条
#   'Foreign flyers' → 1 条
#   "Foreign flyers for Jem's band" → 2 条
#   'Formal'   → 1 条
#   'Fosters a sense of curiosity' → 1 条
#   'Fractured' → 1 条
#   'Friendly' → 1 条
#   'Friendly and humorous' → 1 条
#   'Friends'  → 15 条
#   'Friends and confidants' → 1 条
#   'Frightens the characters' → 1 条
#   'From a light-hearted banter to a strategic discussion.' → 1 条
#   'From an adjacent balcony' → 1 条
#   'From anger to self-delusion' → 1 条
#   'From anticipation to chaos' → 1 条
#   'From anticipation to satisfaction.' → 1 条
#   'From anxiety to excitement' → 1 条
#   'From anxious to calm' → 1 条
#   'From apologetic to confident' → 1 条
#   'From apprehensive to defiant' → 1 条
#   'From awkwardness to comfort.' → 1 条
#   'From boredom to excitement' → 1 条
#   'From calm to alarmed' → 1 条
#   'From calm to angry.' → 1 条
#   'From calm to chaotic' → 8 条
#   'From calm to chaotic.' → 1 条
#   'From calm to panic' → 1 条
#   'From calm to panic.' → 1 条
#   'From calm to tense' → 2 条
#   'From calm to tension' → 1 条
#   'From calmness to chaos' → 1 条
#   'From calmness to tension' → 1 条
#   'From casual to intimate' → 1 条
#   'From caution to panic' → 1 条
#   'From confidence to panic' → 1 条
#   'From confident to insecure' → 1 条
#   'From conflict to resolution' → 1 条
#   'From confusion to acceptance' → 1 条
#   'From confusion to anger' → 1 条
#   'From confusion to fear.' → 1 条
#   'From confusion to understanding.' → 1 条
#   'From coordinated calmness to frantic discord' → 1 条
#   'From curiosity to distress' → 1 条
#   'From curiosity to fear' → 2 条
#   'From curiosity to fear.' → 1 条
#   'From curiosity to understanding.' → 1 条
#   'From defeat to determination' → 1 条
#   'From despair to hope' → 2 条
#   'From excitement to despair' → 1 条
#   'From excitement to disappointment' → 2 条
#   'From excitement to fear' → 5 条
#   'From fear to confidence.' → 1 条
#   'From fear to fear' → 1 条
#   'From fear to relief' → 1 条
#   'From fearful to relieved' → 1 条
#   'From formal to personal.' → 1 条
#   'From friendly to hostile' → 1 条
#   'From friendship to estrangement.' → 1 条
#   'From frustrated to hopeful' → 1 条
#   'From happiness to discomfort.' → 1 条
#   'From heated to panic' → 1 条
#   'From hopeful to horrified' → 1 条
#   'From humorous to chaotic' → 2 条
#   'From humorous to serious' → 2 条
#   'From indifference to care' → 1 条
#   'From indifference to curiosity.' → 1 条
#   'From indifference to determination' → 1 条
#   'From indifference to sadness' → 1 条
#   'From indifferent to curious' → 1 条
#   'From indifferent to passionate' → 1 条
#   'From joking to nostalgic' → 1 条
#   'From neutral to chaotic.' → 1 条
#   'From neutral to hostile' → 2 条
#   'From neutral to supportive' → 1 条
#   'From normal to surreal.' → 1 条
#   'From panic to chaos' → 1 条
#   'From panic to surprise' → 1 条
#   'From passive to assertive.' → 1 条
#   'From peaceful to despairing.' → 1 条
#   'From peaceful to relieved' → 1 条
#   'From playful to grave' → 1 条
#   'From relaxed to tense' → 2 条
#   'From relaxed to tense.' → 1 条
#   'From respectful to defiant' → 1 条
#   'From sad to hopeful' → 1 条
#   'From sadness to anticipation.' → 1 条
#   'From sadness to comfort' → 1 条
#   'From sadness to happiness' → 1 条
#   'From sadness to panic' → 1 条
#   'From serious to humorous' → 1 条
#   'From seriousness to humor.' → 1 条
#   'From shock to anxiety' → 1 条
#   'From shock to fear' → 1 条
#   'From surprise to anger' → 1 条
#   'From surprise to happiness' → 1 条
#   'From surprise to wonder' → 1 条
#   'From tense to friendly' → 1 条
#   'From tense to relieved' → 1 条
#   'From tense to violent' → 1 条
#   'From the broken tunnel wall' → 1 条
#   'From trust to distrust' → 1 条
#   'From violent to emotional' → 1 条
#   'From worried to relieved' → 1 条
#   'From worry to calm' → 1 条
#   'Frosts her pelvis' → 1 条
#   'Frowning' → 2 条
#   'Frustrated' → 1 条
#   'Fumble with the cell phone, or the henchman will regain consciousness' → 1 条
#   'Fumbles with it' → 1 条
#   'Furious, yelling at his men and the situation.' → 1 条
#   'Furrowed brow' → 1 条
#   'Furrowing his brow' → 1 条
#   'Future travel plans' → 1 条
#   "Gabriel's electrocution" → 1 条
#   'Gags'     → 1 条
#   'Garel'    → 2 条
#   'Garnish'  → 1 条
#   'Gary'     → 1 条
#   'Gary cycles with a hamster taped to his back.' → 1 条
#   'Gary cycling with a hamster taped to his back' → 1 条
#   'Gazes out at the city' → 1 条
#   'Gazing'   → 1 条
#   'Gestures for her to sit down' → 1 条
#   'Gestures gratefully' → 1 条
#   'Get Diggs out of the cage, or Diggs will be in danger.' → 1 条
#   'Get Jasper out of the house, or he will attack Bella again.' → 1 条
#   'Get away from her, or she will cast more spells.' → 1 条
#   "Get back for manoeuvres, or he'll be punished." → 1 条
#   'Get back, or Paul will attack her.' → 1 条
#   'Get into the field, or he will be passed over for clandestine service again' → 1 条
#   'Get out of the hole, or he will be eaten' → 1 条
#   'Get rid of the pumpkin spice turd, or Mia and Mel will pull all the shit off.' → 1 条
#   'Get to the helipad, or Maya and Lane will be taken away.' → 1 条
#   'Get to the professor, or he will die.' → 1 条
#   'Gets between them' → 1 条
#   'Gets off the couch' → 1 条
#   'Gets out of bed' → 1 条
#   'Gets tangled in a net' → 1 条
#   'Getting caught by the antagonist' → 1 条
#   'Getting caught by the ranger' → 1 条
#   'Gia'      → 1 条
#   'Gia and Anna discuss the possibility of reusing existing stone.' → 1 条
#   "Gia's flirtatious manner towards Christian, highlighting Anastasia's insistence on respecting marital boundaries and maintaining authority." → 1 条
#   'Gino and Saul grab lamps and use them as improvised weapons, indicating a new level of adaptability.' → 1 条
#   'Give an example, or she will leave' → 1 条
#   'Gives her a dirty look' → 1 条
#   'Gives it back to the man' → 1 条
#   'Gives them a thumbs up' → 1 条
#   'Glares'   → 1 条
#   'Glowing'  → 1 条
#   "Go home, or she'll get hurt." → 1 条
#   'Goes downstairs' → 1 条
#   'Golf club' → 1 条
#   'Grab the banner, or she will fall.' → 1 条
#   'Grab the cigarette, or the fish will die.' → 1 条
#   'Grabbing the garbage' → 1 条
#   'Grabs Julia' → 1 条
#   'Grabs her' → 1 条
#   'Grabs her feet' → 1 条
#   'Grateful but apprehensive' → 1 条
#   'Gray'     → 3 条
#   'Green'    → 6 条
#   'Greet each other' → 1 条
#   'Grey'     → 1 条
#   'Grimace'  → 1 条
#   'Grin'     → 2 条
#   'Grinning' → 1 条
#   'Groggy'   → 1 条
#   'Grows more hostile' → 1 条
#   'Guilty'   → 1 条
#   'Gus'      → 1 条
#   'Gus above, Mistoffelees below' → 1 条
#   'Gus introduces himself, recalls his past, and expresses his opinion on modern theater.' → 1 条
#   'Gus recalls his youth and his time at the pub.' → 1 条
#   'Hair'     → 1 条
#   'Hair color' → 1 条
#   'Handle a situation without Purvis, or it will get complicated.' → 1 条
#   'Hands her a drink' → 1 条
#   'Hands her an envelope' → 1 条
#   'Hands him a soldering iron' → 1 条
#   'Hands it back to him' → 1 条
#   'Hands it to her' → 1 条
#   'Hangs his arm over the bench' → 2 条
#   'Happiness' → 4 条
#   'Happy'    → 1 条
#   'Harassment in the workplace' → 1 条
#   'Hardens'  → 1 条
#   'Harry Turner is curious, and Daryl is helpful' → 1 条
#   'Harry backs off, and Victoria holds her gun steady.' → 1 条
#   'Harry hits a man with a bottle.' → 1 条
#   'Harry is confused, Leonard is angry.' → 1 条
#   "Harry picks up two balls and hits a man's fists." → 1 条
#   "He accepts Shane's actions" → 1 条
#   'He acknowledges his deep romantic feelings for her.' → 1 条
#   'He admits to the crime and justifies it.' → 1 条
#   'He agrees' → 1 条
#   'He aims his harpoon and fires.' → 1 条
#   'He applauds.' → 1 条
#   'He asks why everyone is there.' → 1 条
#   'He attacks Everett.' → 1 条
#   'He backs away and appears in an obstructed view.' → 1 条
#   'He becomes a werewolf' → 1 条
#   'He becomes covered in grease.' → 1 条
#   'He becomes increasingly inappropriate' → 1 条
#   'He becomes increasingly optimistic.' → 1 条
#   'He becomes more aggressive.' → 1 条
#   'He becomes more apologetic' → 1 条
#   'He becomes more confident' → 1 条
#   'He becomes more gentle and affectionate.' → 1 条
#   'He becomes more protective of her' → 1 条
#   'He becomes more protective of her.' → 1 条
#   'He becomes more protective.' → 1 条
#   'He becomes more respectful.' → 1 条
#   'He becomes more submissive' → 1 条
#   'He becomes more supportive and understanding' → 1 条
#   'He becomes more sympathetic.' → 1 条
#   'He becomes more understanding.' → 1 条
#   'He becomes nauseous.' → 1 条
#   'He becomes poisoned' → 1 条
#   'He becomes seductive.' → 1 条
#   'He begins supportive but becomes frustrated and demanding.' → 1 条
#   'He believes Jellystone is too important to give up on' → 1 条
#   'He believes people misunderstand her harmless nature.' → 1 条
#   'He believes she is using him for his money' → 1 条
#   'He brings out Big Bertha.' → 1 条
#   'He buried a pet' → 1 条
#   'He calls out for Alex.' → 1 条
#   'He calls the police.' → 1 条
#   'He calms the situation down.' → 1 条
#   "He can now see Alex's room." → 1 条
#   'He caps it and knocks over his table.' → 1 条
#   'He cares about her.' → 1 条
#   'He carries it for Stella.' → 1 条
#   'He challenges the rival camp to the Olympiad.' → 1 条
#   'He changes his attire' → 1 条
#   'He charges towards the bomb' → 1 条
#   'He checks her pulse' → 1 条
#   'He claims he is protecting her from Vicky.' → 1 条
#   'He claims it.' → 1 条
#   'He claims she was a threat to Claire.' → 1 条
#   'He clenches his jaw and holds onto the jacket.' → 1 条
#   'He comforts her' → 1 条
#   'He concludes that his affection for her is authentic.' → 1 条
#   'He confronts her aggressively' → 1 条
#   'He confronts the midget porn star' → 1 条
#   'He contorts his face, humorously comments on the discovery, and awkwardly tries to explain the situation.' → 1 条
#   'He cracks a joke.' → 1 条
#   'He creases his brow' → 1 条
#   'He creeps into an adjacent room.' → 1 条
#   'He decides to ignore her attempts.' → 1 条
#   'He directly orders Luis to be killed.' → 1 条
#   'He disagrees.' → 1 条
#   "He dismisses Watson's concerns and insists he is fine, even when he clearly shows signs of illness." → 1 条
#   'He dismisses their concerns, insisting on their duty and readiness.' → 1 条
#   "He displays anger and attempts to divert the tourists' focus." → 1 条
#   'He dives into the fish tank to retrieve the cigarette.' → 1 条
#   'He does a somersault.' → 1 条
#   "He doesn't have a reason to change" → 1 条
#   "He doesn't justify it because he doesn't interact directly with Caesar." → 1 条
#   'He drains it.' → 1 条
#   'He draws his wand' → 1 条
#   "He drinks Mrs. Martin's Mushroom Herbal Sleepy-by-Tea." → 1 条
#   'He drops it.' → 1 条
#   'He embraces Jack, then walks angrily to the car.' → 1 条
#   'He encourages it.' → 1 条
#   'He engages in a physical fight.' → 1 条
#   'He expects to see Eva but finds someone else.' → 1 条
#   'He expresses a deep sense of nostalgia.' → 1 条
#   'He expresses concern about someone being in the house.' → 1 条
#   'He eyes Gus keenly' → 1 条
#   'He eyes her worriedly.' → 1 条
#   'He faces her from a doorway.' → 1 条
#   'He faints and falls down' → 1 条
#   'He falls' → 1 条
#   'He feels average' → 1 条
#   'He feels he is being treated unfairly.' → 1 条
#   'He feels humiliated and swears off emotions to focus solely on his intellect.' → 1 条
#   'He feels modern actors lack proper training.' → 1 条
#   'He feels proud' → 1 条
#   'He fidgets in his chair and his expression becomes sheepish.' → 1 条
#   'He finds her amusing' → 1 条
#   'He flashes a smile' → 1 条
#   'He flashes a winning smile' → 1 条
#   'He flies it at low altitudes' → 1 条
#   'He flinches' → 1 条
#   'He flinches noticeably.' → 1 条
#   'He flinches.' → 1 条
#   'He forces the lieutenant and his officers to duck by maneuvering the aircraft close to the ground.' → 1 条
# ...
#   'They greet each other' → 1 条
#   'They grin' → 1 条
#   'They grin.' → 1 条
#   'They have a disagreement and Christian leaves.' → 1 条
#   'They have a private conversation.' → 1 条
#   'They have mixed reactions' → 1 条
#   'They have similar physical appearances' → 1 条
#   'They hear an aircraft approaching.' → 1 条
#   'They help each other' → 1 条
#   'They hide in the rafters.' → 1 条
#   "They hide the queen's body in a trunk and plan to mail her to Africa." → 1 条
#   'They hold their arms out like mummified monsters' → 1 条
#   'They hug her' → 1 条
#   'They hug him' → 1 条
#   'They ignore Butch.' → 1 条
#   'They ignore each other' → 1 条
#   'They increasingly rely on retreat and evasion' → 1 条
#   'They intervene' → 1 条
#   'They investigate.' → 1 条
#   'They join the call.' → 1 条
#   'They leave the scene in disappointment.' → 1 条
#   'They listen' → 1 条
#   'They look confused.' → 1 条
#   'They look through it' → 1 条
#   'They look up at it in confusion' → 1 条
#   'They look up at it with sadness.' → 1 条
#   'They mail her to Africa' → 1 条
#   'They make a truce.' → 1 条
#   'They make eye contact' → 1 条
#   'They make her feel alone.' → 1 条
#   'They make less noise.' → 1 条
#   "They manipulate the Queen's lips with their fingers to make her appear to speak." → 1 条
#   'They nod in agreement' → 1 条
#   'They notice Jen missing when they turn their backs momentarily.' → 1 条
#   'They panic and flail around' → 1 条
#   'They panic and run away.' → 1 条
#   'They physically fight.' → 1 条
#   'They plan to challenge Camp Driftwood to the annual inter-camp Olympiad.' → 1 条
#   'They plan to follow the guide and stay calm.' → 1 条
#   'They praise her.' → 1 条
#   'They provide a means of escape for the characters.' → 1 条
#   'They reject his proposal.' → 1 条
#   'They reject the challenge.' → 1 条
#   'They remain neutral' → 1 条
#   'They remain the same' → 4 条
#   'They remain the same.' → 1 条
#   'They retrieve a snow shovel' → 1 条
#   'They reveal a sense of pride in their actions' → 1 条
#   'They rub against her.' → 1 条
#   'They run away and shout insults back at him.' → 1 条
#   'They say hello' → 1 条
#   'They shatter when she hits the side table.' → 1 条
#   'They shoot at each other' → 1 条
#   'They shout instructions and pull Maya in with a rope, while urging Sarah to speed up.' → 1 条
#   "They show Sherlock Holmes' growing affection for Millicent." → 1 条
#   'They show a mix of concern and panic, trying to understand what is happening.' → 1 条
#   'They smile' → 1 条
#   'They smile and applaud.' → 1 条
#   'They smile at each other' → 1 条
#   'They stare at each other.' → 1 条
#   'They start a truce' → 1 条
#   'They start arguing' → 1 条
#   "They start don't get to interact directly" → 1 条
#   "They start following the guide's instructions more closely." → 1 条
#   'They start helping each other' → 1 条
#   'They start leaving' → 1 条
#   'They start panicking' → 1 条
#   'They start panicking.' → 1 条
#   'They start with a peaceful proposal but become aggressively assertive when met with resistance.' → 1 条
#   'They support Ben and he ultimately wins, leading to celebration from his teammates.' → 1 条
#   'They symbolize her growing isolation.' → 1 条
#   'They symbolize their friendship' → 1 条
#   'They take his picture' → 1 条
#   'They talk' → 2 条
#   'They talk calmly' → 1 条
#   "They tame the aircraft's motions" → 1 条
#   'They throw eggs and paintballs at him' → 1 条
#   'They throw things at each other' → 1 条
#   'They use a thermal suit' → 1 条
#   'They use it to pick a lock' → 1 条
#   'They use the ropes to perform dance steps' → 1 条
#   'They watch in silence' → 1 条
#   'They wear sneakers.' → 1 条
#   'They were utilized by a coven to transport between times and places.' → 1 条
#   'They will become strangers.' → 1 条
#   'They will escape' → 1 条
#   'They will go insane' → 1 条
#   'They work together to hide the body' → 1 条
#   "They're compassionate" → 1 条
#   'Threatening' → 4 条
#   'Threatens her' → 1 条
#   'Threatens him' → 1 条
#   'Three'    → 2 条
#   'Through a calm discussion' → 1 条
#   'Through a company takeover' → 1 条
#   'Through a disagreement about their deployment' → 1 条
#   'Through a paintball and water pistol raid.' → 1 条
#   'Through a series of physical fights' → 1 条
#   'Through a verbal argument' → 1 条
#   'Through a verbal confrontation' → 1 条
#   "Through his father's influence in the agency" → 1 条
#   'Through the ranger' → 1 条
#   'Through verbal insults' → 1 条
#   'Throw jerky to the dog, or it will injure people.' → 1 条
#   'Throws a chair through a window to break it' → 1 条
#   'Throws a paint bomb' → 1 条
#   'Throws up on him' → 1 条
#   'Thwarted feelings.' → 1 条
#   'To add a comedic element.' → 1 条
#   "To add to the gift's presentation." → 1 条
#   'To align the cross on his hand.' → 1 条
#   'To assert his authority' → 1 条
#   'To attack Julia' → 1 条
#   "To avenge his mother's murder" → 1 条
#   'To avenge the injustices suffered by men' → 1 条
#   'To be the tip of the spear in the war' → 1 条
#   "To block Billy's view" → 1 条
#   'To bounce over the canoe.' → 1 条
#   'To build the trap' → 1 条
#   'To call the police' → 1 条
#   'To calm Lila down.' → 1 条
#   'To calm herself down.' → 1 条
#   'To cast spells.' → 1 条
#   'To catch the real killer' → 1 条
#   'To climb down from the window.' → 1 条
#   'To climb to the top of the climbing wall.' → 1 条
#   'To communicate with Isabel.' → 1 条
#   'To communicate with him' → 1 条
#   'To communicate with his deceased uncle.' → 1 条
#   'To communicate with spirits.' → 1 条
#   'To conceal foreign flyers.' → 1 条
#   'To confront the people in the SUV' → 1 条
#   'To contrast it with "continual."' → 1 条
#   'To convey a message' → 1 条
#   'To cover the eyes of a mummified corpse' → 1 条
#   'To create a makeshift bazooka.' → 1 条
#   'To create a sense of isolation and dependence.' → 1 条
#   "To cut the Queen's body." → 1 条
#   'To decorate the set.' → 1 条
#   'To defend herself against Brian' → 1 条
#   'To defend herself.' → 1 条
#   'To deliver a message' → 1 条
#   'To demonstrate the severity of the situation.' → 1 条
#   'To destroy the asteroid' → 1 条
#   'To disable the queen' → 1 条
#   'To distract the henchman' → 1 条
#   'To embrace a mundane, ordinary lifestyle' → 1 条
#   'To empower young men with supernatural abilities for societal domination' → 1 条
#   "To enhance Layla's eyes." → 1 条
#   'To enhance her sensuality' → 1 条
#   'To enslave all mankind after the protection of dogs is eliminated.' → 1 条
#   'To enslave mankind' → 1 条
#   'To ensure Watson remains alive for further experimentation.' → 1 条
#   'To entertain himself.' → 1 条
#   'To entertain the other cats' → 1 条
#   'To escape the gunman' → 1 条
#   "To expose Moriarty's deception." → 1 条
#   'To express her love.' → 1 条
#   'To express his anger and frustration.' → 1 条
#   'To feel connected to his real parents' → 1 条
#   'To fill the silence.' → 1 条
#   'To fly away' → 1 条
#   'To focus on the future' → 1 条
#   "To gain Stella's love over time." → 1 条
#   'To gain understanding' → 1 条
#   'To give up drinking' → 1 条
#   'To haul Fitzroyce out of the water' → 1 条
#   'To head towards Abraham Lincoln Elementary' → 1 条
#   'To help Dan sleep' → 1 条
#   'To hide from the antagonist.' → 1 条
#   'To his right' → 1 条
#   "To hit the man in the hat's groin" → 1 条
#   'To hold animal hair whips' → 1 条
#   'To honor their ancestors' → 1 条
#   'To identify the identity of the spirit communicating with them.' → 1 条
#   'To illuminate the tunnel.' → 1 条
#   'To indicate a sum of money.' → 1 条
#   'To introduce her to his lifestyle.' → 1 条
#   'To jump off the ledge' → 1 条
#   'To keep Edward out.' → 1 条
#   'To kick and shake it.' → 1 条
#   'To lead Starlight' → 1 条
#   'To leave with the other character' → 1 条
#   'To light a cigarette for Manuel.' → 1 条
#   'To listen to music.' → 1 条
#   'To make Diggs more comfortable' → 1 条
#   'To make Jerrika look more mysterious' → 1 条
#   'To make a call.' → 1 条
#   'To make them difficult to detect.' → 1 条
#   'To make them smarter.' → 1 条
#   'To meet back at checkpoint Charlie' → 1 条
#   'To move the scaffolding' → 1 条
#   'To never hurt her.' → 1 条
#   'To observe the shark.' → 1 条
#   'To obstruct the webcam view.' → 1 条
#   'To open a secret compartment.' → 1 条
#   'To open the box.' → 1 条
#   'To pick a lock' → 1 条
#   'To pick the lock' → 1 条
#   'To please him.' → 1 条
#   'To point at portraits.' → 1 条
#   'To prevent Claire from leaving.' → 1 条
#   'To prevent a fight' → 1 条
#   'To protect Bella' → 1 条
#   'To prove the existence of the cursed movie.' → 1 条
#   'To provide drinks for the characters.' → 1 条
#   "To pry open the truck's door." → 1 条
#   "To pull Fairchild's leg." → 1 条
#   'To pull Maya towards the boat' → 1 条
#   'To pull Mia back to safety.' → 1 条
#   'To reach a specific location' → 1 条
#   "To record the dark shape's movements." → 1 条
#   "To record the shark's movements." → 1 条
#   'To release a sound only detectable by dogs, driving them insane' → 1 条
#   'To rescue a friend from a dark room' → 1 条
#   'To rescue a teenage girl' → 1 条
#   'To reveal a hidden message.' → 1 条
#   'To revive the granny.' → 1 条
#   'To rotate over the incense sticks' → 1 条
#   'To rule the world' → 1 条
#   'To scare the group' → 1 条
#   'To seal off the section and prevent further leakage.' → 1 条
#   'To see in the dark.' → 1 条
#   'To sell to vodka shots' → 1 条
#   'To serve Marion dinner.' → 1 条
#   'To shoot the puppet.' → 1 条
#   'To show affection.' → 1 条
#   'To show his commitment to a "vanilla relationship"' → 1 条
#   'To signal for help.' → 1 条
#   'To sit down and rest.' → 1 条
#   "To slam Jason's head against it" → 1 条
#   'To slap herself' → 1 条
#   'To slow down the shark' → 1 条
#   'To smash the mosquito' → 1 条
#   'To smash the mosquito.' → 1 条
#   'To stay low' → 1 条
#   'To steal a picnic basket' → 1 条
#   'To stop Kitty' → 1 条
#   'To stop a killer' → 1 条
#   'To stop the practice.' → 1 条
#   'To store beer.' → 1 条
#   'To store her tarot cards.' → 1 条
#   'To store his EpiPen' → 1 条
#   'To store the incantation.' → 1 条
#   'To swim away from the shark' → 1 条
#   'To swim faster' → 1 条
#   'To switch the glider into stealth mode' → 1 条
#   "To symbolize Holmes's mental struggle." → 1 条
#   'To symbolize her isolation' → 1 条
#   'To symbolize the Hanukkah holiday.' → 1 条
#   'To symbolize their reunion' → 1 条
#   'To test his theory' → 1 条
#   'To test the weight sensor.' → 1 条
#   'To the glass house' → 1 条
#   'To the kitchen' → 1 条
#   'To threaten Anna' → 1 条
#   'To transport Liz and Mia.' → 1 条
#   'To turn on the lights.' → 1 条
#   'To unleash a devastating sound' → 1 条
#   'To use Deuce as bait' → 1 条
#   'To use the glider to fly away' → 1 条
#   'To validate his hypothesis regarding the true cause of death' → 1 条
#   'To view a video.' → 1 条
#   'To wait for her' → 1 条
#   'To ward off unwanted advances.' → 1 条
#   'To warn her' → 1 条
#   'To whisk away his trousers' → 1 条
#   'Toast'    → 2 条
#   'Topples waders' → 1 条
#   'Touch their feet' → 1 条
#   'Touches his wrist' → 1 条
#   "Touching the Delta symbol on the pledge's forehead" → 1 条
#   'Tourist boat light' → 1 条
#   'Training for climbing skills' → 1 条
#   'Trance to tense' → 1 条
#   'Tray'     → 1 条
#   'Tries to walk through them' → 1 条
#   'Triggers her fear' → 1 条
#   'Troubled expression' → 1 条
#   'Truck'    → 1 条
#   'Tugs the wheel' → 1 条
#   'Turn the boat, or he will fall into the water.' → 1 条
#   'Turn to face the police, or they will be arrested.' → 1 条
#   'Turns away' → 3 条
#   'Turns to face Harry' → 1 条
#   'Twice'    → 9 条
#   'Twirls it' → 1 条
#   'Twists and ducks' → 1 条
#   'Two'      → 1 条
#   'Two cans' → 1 条
#   'Two kids in army gear chase Max through the office' → 1 条
#   'Types the address in a message' → 1 条
#   'Typewritten letters' → 1 条
#   'Ugly and disfigured' → 1 条
#   'Unagreeable' → 1 条
#   'Uncertain' → 1 条
#   'Uncertainty' → 1 条
#   'Uncircumcised' → 1 条
#   'Uncle Arthur' → 2 条
#   'Uncle Rudy' → 1 条
#   'Unconscious' → 1 条
#   'Under a starlit sky' → 1 条
#   'Under the blanket' → 1 条
#   'Under the piano' → 1 条
#   'Uneasiness' → 1 条
#   'Uneasy'   → 1 条
#   'Unharmed' → 1 条
#   'Unkown entity' → 1 条
#   'Unleash a sound that drives dogs insane.' → 1 条
#   'Unleash the Call of the Wild, or dogs will go insane.' → 1 条
#   'Unstable' → 1 条
#   'Upstairs' → 2 条
#   'Upturned with a mismatched door' → 1 条
#   'Use his smarts for good, or he will remain average.' → 1 条
#   'Use the collar to unlock the chains binding Diggs, otherwise he will remain restrained.' → 1 条
#   "Uses a table to block Riley's path." → 1 条
#   'Uses it to call the police' → 1 条
#   'Using a collar to pick a lock' → 1 条
#   'Utilizing objects in the environment as offensive tools' → 1 条
#   'Val is angry and defensive, while Blair is calm and supportive.' → 1 条
#   "Vicki's task is purposeful compared to Claire's casual demeanor." → 1 条
#   'Vicky is angry, and Jason is defiant.' → 1 条
#   'Victoria aiming her gun at the bartender.' → 1 条
#   'Victoria enters the bar.' → 1 条
#   'Victoria is skeptical, while Purvis is nonchalant.' → 1 条
#   'Wait for him' → 1 条
#   'Waits for Reed' → 1 条
#   'Walking onto a red carpet' → 1 条
#   'Walking towards her' → 1 条
#   'Walks away' → 1 条
#   'Walks out' → 1 条
#   'Watches Rick' → 1 条
#   'Watches Ryan and Lila go.' → 1 条
#   'Watching a fight.' → 1 条
#   'Watching a ritualistic training video' → 1 条
#   'Watching someone in the stands' → 1 条
#   'Watching them from atop a sign' → 1 条
#   'Watering the flowers' → 1 条
#   'Watson'   → 5 条
#   'Watson accidentally injuring the Queen' → 1 条
#   "Watson checks Victoria's pulse, Holmes glares, and Watson gestures." → 1 条
#   'Watson decides to keep the ring.' → 1 条
#   'Watson experiences redness around the mouth, then temporary brain damage.' → 1 条
#   'Watson experiences temporary brain damage, excruciating abdominal pain, and lactation.' → 1 条
#   'Watson gags on cake, Holmes finds a ring, Holmes vomits.' → 1 条
#   'Watson is panicking, while Holmes is relieved.' → 1 条
#   'Watson pats Holmes on the back while holding a trash bin.' → 1 条
#   'Watson shoots the stenographer' → 1 条
#   'Watson was instrumental' → 1 条
#   "Watson's poisoning" → 1 条
#   'Waves at Billy through the window' → 1 条
#   'Weak'     → 1 条
#   'Wears a gas mask' → 1 条
#   'Wears a purple camouflage outfit' → 1 条
#   'Wet'      → 1 条
#   'When Jack recalls dancing with Isabel late at night on the deserted soundstage.' → 1 条
#   'When he physically prevents her from leaving while making a derogatory suggestion.' → 1 条
#   'Whips and restraints' → 1 条
#   'Whisked away' → 1 条
#   'White'    → 4 条
#   'Wistful'  → 1 条
#   'With Brenda.' → 1 条
#   'With a nod' → 1 条
#   'With amusement' → 1 条
#   'With anger' → 2 条
#   'With disagreement' → 1 条
#   'With disbelief' → 1 条
#   'With excitement' → 1 条
#   'With fear.' → 1 条
#   'With happiness' → 1 条
#   'With her hands' → 1 条
#   'With hesitation' → 1 条
#   'With indifference' → 1 条
#   'With jalape��os' → 1 条
#   'With pride' → 1 条
#   'With relief' → 1 条
#   'With sadness' → 1 条
#   'With surprise' → 2 条
#   'Wooden tray' → 1 条
#   'Working'  → 1 条
#   'Worried'  → 1 条
#   'Worried and concerned' → 1 条
#   'Worried.' → 1 条
#   'Worry'    → 1 条
#   'Yellow'   → 3 条
#   'Yes'      → 1 条
#   'Yes, it foreshadows Edgar escaping.' → 1 条
#   "Yes, it foreshadows Lane's future encounters with the voices." → 1 条
#   'Yes, it foreshadows the arrival of the Komodo dragon' → 1 条
#   'Yes, the blonde lady with the leopard coat foreshadows the identity of the potential killer' → 1 条
#   'Yes, the breaking in foreshadows the lock picking' → 1 条
#   'Yes, the bright blur foreshadows the appearance of a ghost.' → 1 条
#   'Yes, the call to the police foreshadows their arrival' → 1 条
#   'Yes, the encounter with the childlike creature foreshadows the discovery of the missing kids' → 1 条
#   'Yes, the mention of the demon foreshadows the attack.' → 1 条
#   "Yes, the plan foreshadows the group's panic" → 1 条
#   'Yes, the scene where Paul catches the baby road flare foreshadows his decision to go to the helipad' → 1 条
#   'Yogi'     → 2 条
#   'Yogi and Boo-Boo tumble to the ground.' → 1 条
#   'Yogi grabs the shopping cart.' → 1 条
#   'Yogi inspects the worm, Boo-Boo grimaces, Yogi blows the worm out.' → 1 条
#   'Yogi is behind Mr. Ranger' → 1 条
#   'Yogi is embarrassed, while the visitors are supportive.' → 1 条
#   'Yogi sculpts a landscape.' → 1 条
#   'Yogi steals the vending machine, then Ranger Smith confronts him.' → 1 条
#   'Yogi twirls the flaming baton, the cape catches fire, Yogi flaps at the flames.' → 1 条
#   "Yogi's apology and motivational speech" → 2 条
#   'it remains awkward' → 1 条
#   'remains disappointing' → 1 条

# %%
# 运行这段诊断，查看实际的 question_category 值分布
from datasets import load_dataset
from collections import Counter

# dataset = load_dataset('tomg-group-umd/cinepile', split='test')

counter = Counter(dataset[i]['question_category'] for i in range(200))
print("=== question_category 实际值分布 ===")
for val, cnt in sorted(counter.items(), key=lambda x: -x[1]):
    print(f"  {cnt:4d}  {repr(val)}")
# Out:
# === question_category 实际值分布 ===
#     88  'Character and\nRelationship Dynamics'
#     63  'Setting and\nTechnical Analysis'
#     24  'Temporal'
#     13  'Narrative and\nPlot Analysis'
#     12  'Theme Exploration'

# %%
# 快速验证（无需重新加载数据集）
test_categories = [
    'Character and\nRelationship Dynamics',
    'Setting and\nTechnical Analysis',
    'Temporal',
    'Narrative and\nPlot Analysis',
    'Theme Exploration',
]

category_map = {
    'TEMP': 'Temporal',
    'CRD':  'Character and',
    'NPA':  'Narrative and',
    'STA':  'Setting and',
    'TH':   'Theme Exploration',
}

import pandas as pd
df_test = pd.DataFrame({'question_category': test_categories})

print("=== 映射验证 ===")
for abbr, keyword in category_map.items():
    mask = df_test['question_category'].str.contains(keyword, case=False, na=False)
    matched = df_test.loc[mask, 'question_category'].tolist()
    print(f"  {abbr} ({keyword!r:20s}) → {matched}")
# Out:
# === 映射验证 ===
#   TEMP ('Temporal'          ) → ['Temporal']
#   CRD ('Character and'     ) → ['Character and\nRelationship Dynamics']
#   NPA ('Narrative and'     ) → ['Narrative and\nPlot Analysis']
#   STA ('Setting and'       ) → ['Setting and\nTechnical Analysis']
#   TH ('Theme Exploration' ) → ['Theme Exploration']
